# %%
#! pip install xgboost
#!pip install TextBlob
#!pip install nltk
#!pip install tensorflow[and-cuda]
#!pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 34.9 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 23.2 MB/s eta 0:00:00
# Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.2 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 61.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.20.3 safetensors-0.4.2 tokenizers-0.15.2 transformers-4.37.2

# %%
from datetime import datetime, timedelta,date
import pandas as pd
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from __future__ import division
from sklearn.cluster import KMeans
import os

#do not show warnings
import warnings
warnings.filterwarnings("ignore")

#import machine learning related libraries
from sklearn.svm import SVC
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %%
import nltk
import re

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')

from textblob import TextBlob
from textblob.wordnet import Synset
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to /home/jupyter/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
home_dir = '/home/jupyter/data_science_challenges/business_data_science'

data_dir = os.path.join(home_dir, 'data/external/OnlineRetail.csv')

df = pd.read_csv(data_dir, encoding="unicode_escape").drop_duplicates().dropna().reset_index(drop=True)

# Changing data types
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# time series variables
df['date'] = pd.to_datetime(df.InvoiceDate).dt.date
df['year'] = pd.to_datetime(df.InvoiceDate).dt.year
df['month'] = pd.to_datetime(df.InvoiceDate).dt.month
df['day'] = pd.to_datetime(df.InvoiceDate).dt.day
df['yearmo'] = pd.to_datetime(df.InvoiceDate).dt.strftime('%Y%m')
# new variable

df['Revenue'] = df['Quantity'] * df['UnitPrice']

df = df.loc[df.Country == 'United Kingdom']

# %%
def pp(func):
    print('PeePee')
    func()
    
@pp
def pp2():
    print('PeePee2')
# Out:
# PeePee
# PeePee2

# %%
def get_recency_features(df):
    
    df['Recency'] =  (pd.to_datetime(df.InvoiceDate).max() - df.InvoiceDate).dt.days 
    r_df = df.groupby(['CustomerID']).agg({'InvoiceDate': 'min'}).reset_index()\
    .merge(df[['CustomerID', 'InvoiceDate','Recency']], on=['CustomerID','InvoiceDate'], how='inner')\
    .drop_duplicates().reset_index(drop=True).drop(['InvoiceDate'], axis=1).rename(columns={'Recency':'RecencyToDate'})
    
    return r_df

def get_frequency_features(df):
    
    f_df = df[['InvoiceDate','CustomerID']].drop_duplicates().sort_values(by=['CustomerID','InvoiceDate'], ascending=True).reset_index(drop=True)

    #Creating difference between invoice dates per person
    f_df['Offset'] = f_df.groupby(['CustomerID'])['InvoiceDate'].diff().dt.seconds

    # Creating Count per user
    f_df = f_df.merge(\
        f_df.groupby(['CustomerID']).agg(Count = ('InvoiceDate', 'count')).reset_index()\
               ,on=['CustomerID'], how='inner')

    # Finding folks who only had one interaction and giving them an Offset that is differenced from the latest day in the dataset
    f_df.loc[f_df.Count == 1, 'Offset'] = (f_df.InvoiceDate.max() - f_df.InvoiceDate).dt.seconds

    # Dropping the first occurance of a invoicedate.  Not needed to make agg.
    f_df = f_df.loc[~(f_df.Offset.isna())]

    f_df = f_df.groupby(['CustomerID']).agg(FrequencyToDate = ('Offset','median')).reset_index()
    
    return f_df
    

def get_monetary_features(df):
    
    m_df = df[['CustomerID','Revenue']].groupby('CustomerID').agg(RevenueToDate = ('Revenue', 'sum')).reset_index()
    
    return m_df


def get_rfm_features(df):
    
    new_df = df.loc[~df.InvoiceNo.str.contains('C')].copy()
    
    r_df = get_recency_features(new_df)
    f_df = get_frequency_features(new_df)
    m_df = get_monetary_features(new_df)
    
    final_df = r_df.merge(f_df, on='CustomerID', how='inner').merge(m_df, on='CustomerID', how='inner')
    
    return final_df

# %%
work_df = df.merge(get_rfm_features(df), on='CustomerID', how='inner')

# %%
work_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 356642    581416     22809              SET OF 6 T-LIGHTS SANTA         1
# 356643    581416     22807         SET OF 6 T-LIGHTS TOADSTOOLS         2
# 356644    581416    72349B      SET/6 PURPLE BUTTERFLY T-LIGHTS         1
# 356645    581416     22809              SET OF 6 T-LIGHTS SANTA         2
# 356646    581416     23487             SWEET HEART CAKE CARRIER         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country        date  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 356642 2011-12-08 14:58:00       2.95     14569.0  United Kingdom  2011-12-08
# 356643 2011-12-08 14:58:00       1.25     14569.0  United Kingdom  2011-12-08
# 356644 2011-12-08 14:58:00       2.10     14569.0  United Kingdom  2011-12-08
# 356645 2011-12-08 14:58:00       2.95     14569.0  United Kingdom  2011-12-08
# 356646 2011-12-08 14:58:00       9.95     14569.0  United Kingdom  2011-12-08
#
#         year  month  day  yearmo  Revenue  RecencyToDate  FrequencyToDate  \
# 0       2010     12    1  201012    15.30            373             60.0
# 1       2010     12    1  201012    20.34            373             60.0
# 2       2010     12    1  201012    22.00            373             60.0
# 3       2010     12    1  201012    20.34            373             60.0
# 4       2010     12    1  201012    20.34            373             60.0
# ...      ...    ...  ...     ...      ...            ...              ...
# 356642  2011     12    8  201112     2.95              0          78660.0
# 356643  2011     12    8  201112     2.50              0          78660.0
# 356644  2011     12    8  201112     2.10              0          78660.0
# 356645  2011     12    8  201112     5.90              0          78660.0
# 356646  2011     12    8  201112     9.95              0          78660.0
#
#         RevenueToDate
# 0             5391.21
# 1             5391.21
# 2             5391.21
# 3             5391.21
# 4             5391.21
# ...               ...
# 356642         227.39
# 356643         227.39
# 356644         227.39
# 356645         227.39
# 356646         227.39
#
# [356647 rows x 17 columns]

# %%
def interval_purchase(df):

    t_df =df[['CustomerID','InvoiceNo','InvoiceDate']]\
    .drop_duplicates()\
    .sort_values(by=['CustomerID','InvoiceDate'], ascending=True)\
    .groupby(['CustomerID']).agg({'InvoiceDate': 'diff'}).apply(lambda x: x.dt.days).fillna(0)\
    .reset_index().rename(columns={'index':'CustomerID', 'InvoiceDate':'IntervalPurchase'}).fillna(0)
    
    df = df.merge(t_df, on='CustomerID', how='left')
    
    return df

# %%
interval_purchase(work_df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 356642    581416     22809              SET OF 6 T-LIGHTS SANTA         1
# 356643    581416     22807         SET OF 6 T-LIGHTS TOADSTOOLS         2
# 356644    581416    72349B      SET/6 PURPLE BUTTERFLY T-LIGHTS         1
# 356645    581416     22809              SET OF 6 T-LIGHTS SANTA         2
# 356646    581416     23487             SWEET HEART CAKE CARRIER         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country        date  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 356642 2011-12-08 14:58:00       2.95     14569.0  United Kingdom  2011-12-08
# 356643 2011-12-08 14:58:00       1.25     14569.0  United Kingdom  2011-12-08
# 356644 2011-12-08 14:58:00       2.10     14569.0  United Kingdom  2011-12-08
# 356645 2011-12-08 14:58:00       2.95     14569.0  United Kingdom  2011-12-08
# 356646 2011-12-08 14:58:00       9.95     14569.0  United Kingdom  2011-12-08
#
#         year  month  day  yearmo  Revenue  RecencyToDate  FrequencyToDate  \
# 0       2010     12    1  201012    15.30            373             60.0
# 1       2010     12    1  201012    20.34            373             60.0
# 2       2010     12    1  201012    22.00            373             60.0
# 3       2010     12    1  201012    20.34            373             60.0
# 4       2010     12    1  201012    20.34            373             60.0
# ...      ...    ...  ...     ...      ...            ...              ...
# 356642  2011     12    8  201112     2.95              0          78660.0
# 356643  2011     12    8  201112     2.50              0          78660.0
# 356644  2011     12    8  201112     2.10              0          78660.0
# 356645  2011     12    8  201112     5.90              0          78660.0
# 356646  2011     12    8  201112     9.95              0          78660.0
#
#         RevenueToDate  IntervalPurchase
# 0             5391.21               NaN
# 1             5391.21               NaN
# 2             5391.21               NaN
# 3             5391.21               NaN
# 4             5391.21               NaN
# ...               ...               ...
# 356642         227.39               NaN
# 356643         227.39               NaN
# 356644         227.39               NaN
# 356645         227.39               NaN
# 356646         227.39               NaN
#
# [356647 rows x 18 columns]

# %%
work_df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'date', 'year', 'month', 'day',
#        'yearmo', 'Revenue', 'RecencyToDate', 'FrequencyToDate',
#        'RevenueToDate'],
#       dtype='object')

# %%
 w = work_df.Description.unique()

# %%
w
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'LETTER "U" BLING KEY RING',
#        'LETTER "W" BLING KEY RING', 'LETTER "Z" BLING KEY RING'],
#       dtype=object)

# %%
w = [TextBlob(i) for i in w]
w = [i.ngrams(n=3) for i in w]
l = []
for i in w:
    l.extend(i)

# %%
pd.DataFrame(pd.DataFrame(l).value_counts()).head(50)
# Out:
#                                 count
# 0           1        2
# SET         OF       4             31
#                      6             27
# BLING       KEY      RING          25
# HOT         WATER    BOTTLE        24
# PACK        OF       12            23
# SET         OF       3             23
# HOME        SWEET    HOME          21
# I           LOVE     LONDON        16
# TRAVEL      CARD     WALLET        13
# 50          'S       CHRISTMAS     12
# SET         OF       2             12
# NUMBER      TILE     COTTAGE       11
# BLUE        METAL    DOOR          11
# TILE        COTTAGE  GARDEN        11
# METAL       DOOR     SIGN          11
# TILE        VINTAGE  FONT          11
# NUMBER      TILE     VINTAGE       11
# FRENCH      BLUE     METAL         11
# PACK        OF       6             11
# SET         OF       36            10
# HEART       T-LIGHT  HOLDER        10
# EMBROIDERED RIBBON   REEL          10
# ASSORTED    TUTTI    FRUTTI        10
# MIRRORED    WALL     ART           10
# BEADED      CRYSTAL  HEART          9
# MAGIC       DRAWING  SLATE          9
# IN          GIFT     BOX            8
# SET         OF       12             8
# PAPER       LANTERN  9              7
# OF          4        KNICK          7
# VINTAGE     UNION    JACK           7
# OF          4        NAPKIN         7
# 4           NAPKIN   CHARMS         7
# KNICK       KNACK    TINS           7
# LANTERN     9        POINT          7
# STAR        T-LIGHT  HOLDER         7
# DROP        EARRINGS W              7
# 4           KNICK    KNACK          7
# OF          6        T-LIGHTS       6
# PACK        OF       4              6
# COTTON      TOTE     BAG            6
# FIRE        POLISHED GLASS          6
# POLYESTER   FILLER   PAD            6
# DINER       WALL     CLOCK          6
# PLASTERS    IN       TIN            6
# GLASS       BEAD     HOOP           6
# MAGNETS     PACK     OF             6
# CERAMIC     DRAWER   KNOB           6
# SIGN        BLUE     METAL          6
# TV          DINNER   TRAY           6

# %%
# Out:
# [WordList(['WHITE', 'HANGING', 'HEART']),
#  WordList(['HANGING', 'HEART', 'T-LIGHT']),
#  WordList(['HEART', 'T-LIGHT', 'HOLDER']),
#  WordList(['WHITE', 'METAL', 'LANTERN']),
#  WordList(['CREAM', 'CUPID', 'HEARTS']),
#  WordList(['CUPID', 'HEARTS', 'COAT']),
#  WordList(['HEARTS', 'COAT', 'HANGER']),
#  WordList(['KNITTED', 'UNION', 'FLAG']),
#  WordList(['UNION', 'FLAG', 'HOT']),
#  WordList(['FLAG', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['RED', 'WOOLLY', 'HOTTIE']),
#  WordList(['WOOLLY', 'HOTTIE', 'WHITE']),
#  WordList(['HOTTIE', 'WHITE', 'HEART']),
#  WordList(['SET', '7', 'BABUSHKA']),
#  WordList(['7', 'BABUSHKA', 'NESTING']),
#  WordList(['BABUSHKA', 'NESTING', 'BOXES']),
#  WordList(['GLASS', 'STAR', 'FROSTED']),
#  WordList(['STAR', 'FROSTED', 'T-LIGHT']),
#  WordList(['FROSTED', 'T-LIGHT', 'HOLDER']),
#  WordList(['HAND', 'WARMER', 'UNION']),
#  WordList(['WARMER', 'UNION', 'JACK']),
#  WordList(['HAND', 'WARMER', 'RED']),
#  WordList(['WARMER', 'RED', 'POLKA']),
#  WordList(['RED', 'POLKA', 'DOT']),
#  WordList(['EDWARDIAN', 'PARASOL', 'RED']),
#  WordList(['RETRO', 'COFFEE', 'MUGS']),
#  WordList(['COFFEE', 'MUGS', 'ASSORTED']),
#  WordList(['SAVE', 'THE', 'PLANET']),
#  WordList(['THE', 'PLANET', 'MUG']),
#  WordList(['VINTAGE', 'BILLBOARD', 'DRINK']),
#  WordList(['BILLBOARD', 'DRINK', 'ME']),
#  WordList(['DRINK', 'ME', 'MUG']),
#  WordList(['VINTAGE', 'BILLBOARD', 'LOVE/HATE']),
#  WordList(['BILLBOARD', 'LOVE/HATE', 'MUG']),
#  WordList(['WOOD', '2', 'DRAWER']),
#  WordList(['2', 'DRAWER', 'CABINET']),
#  WordList(['DRAWER', 'CABINET', 'WHITE']),
#  WordList(['CABINET', 'WHITE', 'FINISH']),
#  WordList(['WOOD', 'S/3', 'CABINET']),
#  WordList(['S/3', 'CABINET', 'ANT']),
#  WordList(['CABINET', 'ANT', 'WHITE']),
#  WordList(['ANT', 'WHITE', 'FINISH']),
#  WordList(['WOODEN', 'PICTURE', 'FRAME']),
#  WordList(['PICTURE', 'FRAME', 'WHITE']),
#  WordList(['FRAME', 'WHITE', 'FINISH']),
#  WordList(['WOODEN', 'FRAME', 'ANTIQUE']),
#  WordList(['FRAME', 'ANTIQUE', 'WHITE']),
#  WordList(['EDWARDIAN', 'PARASOL', 'BLACK']),
#  WordList(['IVORY', 'EMBROIDERED', 'QUILT']),
#  WordList(['JUMBO', 'SHOPPER', 'VINTAGE']),
#  WordList(['SHOPPER', 'VINTAGE', 'RED']),
#  WordList(['VINTAGE', 'RED', 'PAISLEY']),
#  WordList(['HAND', 'WARMER', 'RED']),
#  WordList(['WARMER', 'RED', 'RETROSPOT']),
#  WordList(['GIN', 'AND', 'TONIC']),
#  WordList(['AND', 'TONIC', 'MUG']),
#  WordList(['COLOUR', 'GLASS', 'STAR']),
#  WordList(['GLASS', 'STAR', 'T-LIGHT']),
#  WordList(['STAR', 'T-LIGHT', 'HOLDER']),
#  WordList(['YOU', "'RE", 'CONFUSING']),
#  WordList(["'RE", 'CONFUSING', 'ME']),
#  WordList(['CONFUSING', 'ME', 'METAL']),
#  WordList(['ME', 'METAL', 'SIGN']),
#  WordList(['ASSORTED', 'COLOUR', 'BIRD']),
#  WordList(['COLOUR', 'BIRD', 'ORNAMENT']),
#  WordList(['POPPY', "'S", 'PLAYHOUSE']),
#  WordList(["'S", 'PLAYHOUSE', 'BEDROOM']),
#  WordList(['POPPY', "'S", 'PLAYHOUSE']),
#  WordList(["'S", 'PLAYHOUSE', 'KITCHEN']),
#  WordList(['FELTCRAFT', 'PRINCESS', 'CHARLOTTE']),
#  WordList(['PRINCESS', 'CHARLOTTE', 'DOLL']),
#  WordList(['IVORY', 'KNITTED', 'MUG']),
#  WordList(['KNITTED', 'MUG', 'COSY']),
#  WordList(['BOX', 'OF', '6']),
#  WordList(['OF', '6', 'ASSORTED']),
#  WordList(['6', 'ASSORTED', 'COLOUR']),
#  WordList(['ASSORTED', 'COLOUR', 'TEASPOONS']),
#  WordList(['BOX', 'OF', 'VINTAGE']),
#  WordList(['OF', 'VINTAGE', 'JIGSAW']),
#  WordList(['VINTAGE', 'JIGSAW', 'BLOCKS']),
#  WordList(['BOX', 'OF', 'VINTAGE']),
#  WordList(['OF', 'VINTAGE', 'ALPHABET']),
#  WordList(['VINTAGE', 'ALPHABET', 'BLOCKS']),
#  WordList(['HOME', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['LOVE', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['RECIPE', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'METAL']),
#  WordList(['WITH', 'METAL', 'HEART']),
#  WordList(['DOORMAT', 'NEW', 'ENGLAND']),
#  WordList(['JAM', 'MAKING', 'SET']),
#  WordList(['MAKING', 'SET', 'WITH']),
#  WordList(['SET', 'WITH', 'JARS']),
#  WordList(['RED', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['YELLOW', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['BLUE', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['BATH', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['FELTCRAFT', 'DOLL', 'EMILY']),
#  WordList(['WRAP', 'ENGLISH', 'ROSE']),
#  WordList(['PHOTO', 'FRAME', 'CORNICE']),
#  WordList(['WRAP', 'DOLLY', 'GIRL']),
#  WordList(['WRAP', 'DOILEY', 'DESIGN']),
#  WordList(['SET', 'OF', '12']),
#  WordList(['OF', '12', 'VINTAGE']),
#  WordList(['12', 'VINTAGE', 'POSTCARD']),
#  WordList(['VINTAGE', 'POSTCARD', 'SET']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'VINTAGE']),
#  WordList(['6', 'VINTAGE', 'NOTELETS']),
#  WordList(['VINTAGE', 'NOTELETS', 'KIT']),
#  WordList(['SWEETHEART', 'WIRE', 'WALL']),
#  WordList(['WIRE', 'WALL', 'TIDY']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'SPICE']),
#  WordList(['6', 'SPICE', 'TINS']),
#  WordList(['SPICE', 'TINS', 'PANTRY']),
#  WordList(['TINS', 'PANTRY', 'DESIGN']),
#  WordList(['JAM', 'MAKING', 'SET']),
#  WordList(['MAKING', 'SET', 'PRINTED']),
#  WordList(['HOMEMADE', 'JAM', 'SCENTED']),
#  WordList(['JAM', 'SCENTED', 'CANDLES']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'CAKE']),
#  WordList(['3', 'CAKE', 'TINS']),
#  WordList(['CAKE', 'TINS', 'PANTRY']),
#  WordList(['TINS', 'PANTRY', 'DESIGN']),
#  WordList(['PINK', 'CREAM', 'FELT']),
#  WordList(['CREAM', 'FELT', 'CRAFT']),
#  WordList(['FELT', 'CRAFT', 'TRINKET']),
#  WordList(['CRAFT', 'TRINKET', 'BOX']),
#  WordList(['MAKE', 'YOUR', 'OWN']),
#  WordList(['YOUR', 'OWN', 'FLOWERPOWER']),
#  WordList(['OWN', 'FLOWERPOWER', 'CARD']),
#  WordList(['FLOWERPOWER', 'CARD', 'KIT']),
#  WordList(['GLASS', 'BEURRE', 'DISH']),
#  WordList(['DOORMAT', 'ENGLISH', 'ROSE']),
#  WordList(['DOORMAT', 'WELCOME', 'TO']),
#  WordList(['WELCOME', 'TO', 'OUR']),
#  WordList(['TO', 'OUR', 'HOME']),
#  WordList(['WOODEN', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'BUNTING']),
#  WordList(['WOODEN', 'ROUNDERS', 'GARDEN']),
#  WordList(['ROUNDERS', 'GARDEN', 'SET']),
#  WordList(['KEY', 'FOB', 'FRONT']),
#  WordList(['FOB', 'FRONT', 'DOOR']),
#  WordList(['KEY', 'FOB', 'BACK']),
#  WordList(['FOB', 'BACK', 'DOOR']),
#  WordList(['KEY', 'FOB', 'GARAGE']),
#  WordList(['FOB', 'GARAGE', 'DESIGN']),
#  WordList(['KEY', 'FOB', 'SHED']),
#  WordList(['6', 'RIBBONS', 'RUSTIC']),
#  WordList(['RIBBONS', 'RUSTIC', 'CHARM']),
#  WordList(['IVORY', 'SWEETHEART', 'WIRE']),
#  WordList(['SWEETHEART', 'WIRE', 'LETTER']),
#  WordList(['WIRE', 'LETTER', 'RACK']),
#  WordList(['TOILET', 'SIGN', 'OCCUPIED']),
#  WordList(['SIGN', 'OCCUPIED', 'OR']),
#  WordList(['OCCUPIED', 'OR', 'VACANT']),
#  WordList(['REGENCY', 'CAKE', 'FORK']),
#  WordList(['REGENCY', 'TEA', 'SPOON']),
#  WordList(['REGENCY', 'SUGAR', 'TONGS']),
#  WordList(['REGENCY', 'TEA', 'STRAINER']),
#  WordList(['REGENCY', 'CAKE', 'SLICE']),
#  WordList(['TREASURE', 'ISLAND', 'BOOK']),
#  WordList(['ISLAND', 'BOOK', 'BOX']),
#  WordList(['ABC', 'TREASURE', 'BOOK']),
#  WordList(['TREASURE', 'BOOK', 'BOX']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'FLOWER']),
#  WordList(['WALLET', 'FLOWER', 'MEADOW']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'VINTAGE']),
#  WordList(['WALLET', 'VINTAGE', 'TICKET']),
#  WordList(['EDWARDIAN', 'HEART', 'PHOTO']),
#  WordList(['HEART', 'PHOTO', 'FRAME']),
#  WordList(['FELTCRAFT', 'GIRL', 'AMELIE']),
#  WordList(['GIRL', 'AMELIE', 'KIT']),
#  WordList(['FOOD', 'COVER', 'WITH']),
#  WordList(['COVER', 'WITH', 'BEADS']),
#  WordList(['WITH', 'BEADS', 'SET']),
#  WordList(['BEADS', 'SET', '2']),
#  WordList(['REGENCY', 'CAKESTAND', '3']),
#  WordList(['CAKESTAND', '3', 'TIER']),
#  WordList(['VINTAGE', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'BUNTING']),
#  WordList(['LARGE', 'ANTIQUE', 'WHITE']),
#  WordList(['ANTIQUE', 'WHITE', 'PHOTO']),
#  WordList(['WHITE', 'PHOTO', 'FRAME']),
#  WordList(['PARISIENNE', 'CURIO', 'CABINET']),
#  WordList(['PARISIENNE', 'KEY', 'CABINET']),
#  WordList(['PARISIENNE', 'SEWING', 'BOX']),
#  WordList(['PARISIENNE', 'JEWELLERY', 'DRAWER']),
#  WordList(['SMALL', 'PARISIENNE', 'HEART']),
#  WordList(['PARISIENNE', 'HEART', 'PHOTO']),
#  WordList(['HEART', 'PHOTO', 'FRAME']),
#  WordList(['GLASS', 'BON', 'BON']),
#  WordList(['BON', 'BON', 'JAR']),
#  WordList(['CLASSIC', 'SUGAR', 'DISPENSER']),
#  WordList(['DOILEY', 'STORAGE', 'TIN']),
#  WordList(['SET', 'OF', '4']),
#  WordList(['OF', '4', 'KNICK']),
#  WordList(['4', 'KNICK', 'KNACK']),
#  WordList(['KNICK', 'KNACK', 'TINS']),
#  WordList(['KNACK', 'TINS', 'DOILEY']),
#  WordList(['REGENCY', 'MILK', 'JUG']),
#  WordList(['MILK', 'JUG', 'PINK']),
#  WordList(['REGENCY', 'TEAPOT', 'ROSES']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'REGENCY']),
#  WordList(['3', 'REGENCY', 'CAKE']),
#  WordList(['REGENCY', 'CAKE', 'TINS']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'IVORY']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'PINK']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'GREEN']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'BLUE']),
#  WordList(['FRENCH', 'ENAMEL', 'CANDLEHOLDER']),
#  WordList(['PAPER', 'BUNTING', 'RETROSPOT']),
#  WordList(['PAPER', 'BUNTING', 'VINTAGE']),
#  WordList(['BUNTING', 'VINTAGE', 'PAISLEY']),
#  WordList(['PAPER', 'BUNTING', 'COLOURED']),
#  WordList(['BUNTING', 'COLOURED', 'LACE']),
#  WordList(['WRAP', 'PAISLEY', 'PARK']),
#  WordList(['WRAP', 'RED', 'DOILEY']),
#  WordList(['WRAP', 'GINGHAM', 'ROSE']),
#  WordList(['RIBBON', 'REEL', 'CHRISTMAS']),
#  WordList(['REEL', 'CHRISTMAS', 'SOCK']),
#  WordList(['CHRISTMAS', 'SOCK', 'BAUBLE']),
#  WordList(['3', 'RAFFIA', 'RIBBONS']),
#  WordList(['RAFFIA', 'RIBBONS', 'VINTAGE']),
#  WordList(['RIBBONS', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['TRADITIONAL', 'KNITTING', 'NANCY']),
#  WordList(['DOORMAT', 'WELCOME', 'PUPPIES']),
#  WordList(['CHILDREN', "'S", 'APRON']),
#  WordList(["'S", 'APRON', 'DOLLY']),
#  WordList(['APRON', 'DOLLY', 'GIRL']),
#  WordList(['CHILDRENS', 'APRON', 'SPACEBOY']),
#  WordList(['APRON', 'SPACEBOY', 'DESIGN']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'SALLY']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'SUSIE']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'EMILY']),
#  WordList(['PANTRY', 'MAGNETIC', 'SHOPPING']),
#  WordList(['MAGNETIC', 'SHOPPING', 'LIST']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'SNACK']),
#  WordList(['6', 'SNACK', 'LOAF']),
#  WordList(['SNACK', 'LOAF', 'BAKING']),
#  WordList(['LOAF', 'BAKING', 'CASES']),
#  WordList(['SET', 'OF', '12']),
#  WordList(['OF', '12', 'MINI']),
#  WordList(['12', 'MINI', 'LOAF']),
#  WordList(['MINI', 'LOAF', 'BAKING']),
#  WordList(['LOAF', 'BAKING', 'CASES']),
#  WordList(['DRAWER', 'KNOB', 'VINTAGE']),
#  WordList(['KNOB', 'VINTAGE', 'GLASS']),
#  WordList(['VINTAGE', 'GLASS', 'BALL']),
#  WordList(['CARD', 'HOLDER', 'LOVE']),
#  WordList(['HOLDER', 'LOVE', 'BIRD']),
#  WordList(['LOVE', 'BIRD', 'LARGE']),
#  WordList(['FOOT', 'STOOL', 'HOME']),
#  WordList(['STOOL', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['PETIT', 'TRAY', 'CHIC']),
#  WordList(['SWEET', 'HEART', 'CAKE']),
#  WordList(['HEART', 'CAKE', 'CARRIER']),
#  WordList(['PACK', 'OF', 'SIX']),
#  WordList(['OF', 'SIX', 'LED']),
#  WordList(['SIX', 'LED', 'TEA']),
#  WordList(['LED', 'TEA', 'LIGHTS']),
#  WordList(['3', 'RAFFIA', 'RIBBONS']),
#  WordList(['RAFFIA', 'RIBBONS', '50']),
#  WordList(['RIBBONS', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', '50']),
#  WordList(['KIT', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(['SCANDINAVIAN', 'REDS', 'RIBBONS']),
#  WordList(['BISCUIT', 'TIN', 'VINTAGE']),
#  WordList(['TIN', 'VINTAGE', 'GREEN']),
#  WordList(['ROUND', 'CAKE', 'TIN']),
#  WordList(['CAKE', 'TIN', 'VINTAGE']),
#  WordList(['TIN', 'VINTAGE', 'GREEN']),
#  WordList(['3', 'TIER', 'CAKE']),
#  WordList(['TIER', 'CAKE', 'TIN']),
#  WordList(['CAKE', 'TIN', 'GREEN']),
#  WordList(['TIN', 'GREEN', 'AND']),
#  WordList(['GREEN', 'AND', 'CREAM']),
#  WordList(['PACK', 'OF', '20']),
#  WordList(['OF', '20', 'NAPKINS']),
#  WordList(['20', 'NAPKINS', 'PANTRY']),
#  WordList(['NAPKINS', 'PANTRY', 'DESIGN']),
#  WordList(['PACK', 'OF', '6']),
#  WordList(['OF', '6', 'BIRDY']),
#  WordList(['6', 'BIRDY', 'GIFT']),
#  WordList(['BIRDY', 'GIFT', 'TAGS']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', 'EMPIRE']),
#  WordList(['STRAWBERRY', 'CERAMIC', 'TRINKET']),
#  WordList(['CERAMIC', 'TRINKET', 'BOX']),
#  WordList(['NATURAL', 'SLATE', 'HEART']),
#  WordList(['SLATE', 'HEART', 'CHALKBOARD']),
#  WordList(['PACK', 'OF', '12']),
#  WordList(['OF', '12', '50']),
#  WordList(['12', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'TISSUES']),
#  WordList(['HEART', 'SHAPED', 'HOLLY']),
#  WordList(['SHAPED', 'HOLLY', 'WREATH']),
#  WordList(['36', 'DOILIES', 'VINTAGE']),
#  WordList(['DOILIES', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['ROLL', 'WRAP', '50']),
#  WordList(['WRAP', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(['ROLL', 'WRAP', 'VINTAGE']),
#  WordList(['WRAP', 'VINTAGE', 'SPOT']),
#  WordList(['BOX', 'OF', '6']),
#  WordList(['OF', '6', 'MINI']),
#  WordList(['6', 'MINI', '50']),
#  WordList(['MINI', '50', "'S"]),
#  WordList(['50', "'S", 'CRACKERS']),
#  WordList(['6', 'GIFT', 'TAGS']),
#  WordList(['GIFT', 'TAGS', '50']),
#  WordList(['TAGS', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(['ANTIQUE', 'SILVER', 'T-LIGHT']),
#  WordList(['SILVER', 'T-LIGHT', 'GLASS']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'RIBBONS']),
#  WordList(['6', 'RIBBONS', 'VINTAGE']),
#  WordList(['RIBBONS', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['60', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', 'VINTAGE']),
#  WordList(['CASES', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['GLASS', 'APOTHECARY', 'BOTTLE']),
#  WordList(['APOTHECARY', 'BOTTLE', 'TONIC']),
#  WordList(['GLASS', 'APOTHECARY', 'BOTTLE']),
#  WordList(['APOTHECARY', 'BOTTLE', 'PERFUME']),
#  WordList(['VICTORIAN', 'SEWING', 'BOX']),
#  WordList(['SEWING', 'BOX', 'LARGE']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'TEA']),
#  WordList(['BOTTLE', 'TEA', 'AND']),
#  WordList(['TEA', 'AND', 'SYMPATHY']),
#  WordList(['RED', 'HANGING', 'HEART']),
#  WordList(['HANGING', 'HEART', 'T-LIGHT']),
#  WordList(['HEART', 'T-LIGHT', 'HOLDER']),
#  WordList(['WOOD', 'BLACK', 'BOARD']),
#  WordList(['BLACK', 'BOARD', 'ANT']),
#  WordList(['BOARD', 'ANT', 'WHITE']),
#  WordList(['ANT', 'WHITE', 'FINISH']),
#  WordList(['ENAMEL', 'BREAD', 'BIN']),
#  WordList(['BREAD', 'BIN', 'CREAM']),
#  WordList(['MEMO', 'BOARD', 'COTTAGE']),
#  WordList(['BOARD', 'COTTAGE', 'DESIGN']),
#  WordList(['FAMILY', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'CORNICE']),
#  WordList(['PICTURE', 'FRAME', 'WOOD']),
#  WordList(['FRAME', 'WOOD', 'TRIPLE']),
#  WordList(['WOOD', 'TRIPLE', 'PORTRAIT']),
#  WordList(['PAINTED', 'METAL', 'PEARS']),
#  WordList(['METAL', 'PEARS', 'ASSORTED']),
#  WordList(['CREAM', 'SWEETHEART', 'MINI']),
#  WordList(['SWEETHEART', 'MINI', 'CHEST']),
#  WordList(['PHOTO', 'FRAME', '3']),
#  WordList(['FRAME', '3', 'CLASSIC']),
#  WordList(['3', 'CLASSIC', 'HANGING']),
#  WordList(['HEART', 'FILIGREE', 'DOVE']),
#  WordList(['FILIGREE', 'DOVE', 'SMALL']),
#  WordList(['WHITE', 'WOOD', 'GARDEN']),
#  WordList(['WOOD', 'GARDEN', 'PLANT']),
#  WordList(['GARDEN', 'PLANT', 'LADDER']),
#  WordList(['DOORMAT', 'RED', 'RETROSPOT']),
#  WordList(['COLOUR', 'GLASS', 'T-LIGHT']),
#  WordList(['GLASS', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'HANGING']),
#  WordList(['VINTAGE', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'MEMOBOARD']),
#  WordList(['ROSE', 'COTTAGE', 'KEEPSAKE']),
#  WordList(['COTTAGE', 'KEEPSAKE', 'BOX']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'NOTEBOOKS']),
#  WordList(['3', 'NOTEBOOKS', 'IN']),
#  WordList(['NOTEBOOKS', 'IN', 'PARCEL']),
#  WordList(['CUPBOARD', '3', 'DRAWER']),
#  WordList(['3', 'DRAWER', 'MA']),
#  WordList(['DRAWER', 'MA', 'CAMPAGNE']),
#  WordList(['GARLAND', 'WOODEN', 'HAPPY']),
#  WordList(['WOODEN', 'HAPPY', 'EASTER']),
#  WordList(['HANGING', 'METAL', 'RABBIT']),
#  WordList(['METAL', 'RABBIT', 'DECORATION']),
#  WordList(['HOT', 'BATHS', 'SOAP']),
#  WordList(['BATHS', 'SOAP', 'HOLDER']),
#  WordList(['DOORMAT', 'FAIRY', 'CAKE']),
#  WordList(['DOORMAT', 'SPOTTY', 'HOME']),
#  WordList(['SPOTTY', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['LOVEBIRD', 'HANGING', 'DECORATION']),
#  WordList(['HANGING', 'DECORATION', 'WHITE']),
#  WordList(['METAL', '4', 'HOOK']),
#  WordList(['4', 'HOOK', 'HANGER']),
#  WordList(['HOOK', 'HANGER', 'FRENCH']),
#  WordList(['HANGER', 'FRENCH', 'CHATEAU']),
#  WordList(['CREAM', 'HEART', 'CARD']),
#  WordList(['HEART', 'CARD', 'HOLDER']),
#  WordList(['DOORMAT', 'UNION', 'FLAG']),
#  WordList(['DOORMAT', '3', 'SMILEY']),
#  WordList(['3', 'SMILEY', 'CATS']),
#  WordList(['VICTORIAN', 'SEWING', 'BOX']),
#  WordList(['SEWING', 'BOX', 'SMALL']),
#  WordList(['SINGLE', 'HEART', 'ZINC']),
#  WordList(['HEART', 'ZINC', 'T-LIGHT']),
#  WordList(['ZINC', 'T-LIGHT', 'HOLDER']),
#  WordList(['FINE', 'WICKER', 'HEART']),
#  WordList(['FOUR', 'HOOK', 'WHITE']),
#  WordList(['HOOK', 'WHITE', 'LOVEBIRDS']),
#  WordList(['POLYESTER', 'FILLER', 'PAD']),
#  WordList(['FILLER', 'PAD', '40x40cm']),
#  WordList(['CREAM', 'WALL', 'PLANTER']),
#  WordList(['WALL', 'PLANTER', 'HEART']),
#  WordList(['PLANTER', 'HEART', 'SHAPED']),
#  WordList(['DOORMAT', 'FANCY', 'FONT']),
#  WordList(['FANCY', 'FONT', 'HOME']),
#  WordList(['FONT', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['LANTERN', 'CREAM', 'GAZEBO']),
#  WordList(['WHITE', 'SPOT', 'BLUE']),
#  WordList(['SPOT', 'BLUE', 'CERAMIC']),
#  WordList(['BLUE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['WHITE', 'SPOT', 'RED']),
#  WordList(['SPOT', 'RED', 'CERAMIC']),
#  WordList(['RED', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['BLUE', 'STRIPE', 'CERAMIC']),
#  WordList(['STRIPE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['RED', 'STRIPE', 'CERAMIC']),
#  WordList(['STRIPE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['VINTAGE', 'CREAM', 'DOG']),
#  WordList(['CREAM', 'DOG', 'FOOD']),
#  WordList(['DOG', 'FOOD', 'CONTAINER']),
#  WordList(['DOG', 'BOWL', 'VINTAGE']),
#  WordList(['BOWL', 'VINTAGE', 'CREAM']),
#  WordList(['VINTAGE', 'CREAM', 'CAT']),
#  WordList(['CREAM', 'CAT', 'FOOD']),
#  WordList(['CAT', 'FOOD', 'CONTAINER']),
#  WordList(['CAT', 'BOWL', 'VINTAGE']),
#  WordList(['BOWL', 'VINTAGE', 'CREAM']),
#  WordList(['BLUE', 'SPOT', 'CERAMIC']),
#  WordList(['SPOT', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['WOODEN', 'STAR', 'CHRISTMAS']),
#  WordList(['STAR', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['WOODEN', 'TREE', 'CHRISTMAS']),
#  WordList(['TREE', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['WOODEN', 'HEART', 'CHRISTMAS']),
#  WordList(['HEART', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['CHOCOLATE', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'KEEP']),
#  WordList(['BOTTLE', 'KEEP', 'CALM']),
#  WordList(['JUMBO', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'POLKADOT']),
#  WordList(['JUMBO', 'BAG', 'BAROQUE']),
#  WordList(['BAG', 'BAROQUE', 'BLACK']),
#  WordList(['BAROQUE', 'BLACK', 'WHITE']),
#  WordList(['JUMBO', 'BAG', 'CHARLIE']),
#  WordList(['BAG', 'CHARLIE', 'AND']),
#  WordList(['CHARLIE', 'AND', 'LOLA']),
#  WordList(['AND', 'LOLA', 'TOYS']),
#  WordList(['STRAWBERRY', 'CHARLOTTE', 'BAG']),
#  WordList(['RED', '3', 'PIECE']),
#  WordList(['3', 'PIECE', 'RETROSPOT']),
#  WordList(['PIECE', 'RETROSPOT', 'CUTLERY']),
#  WordList(['RETROSPOT', 'CUTLERY', 'SET']),
#  WordList(['BLUE', '3', 'PIECE']),
#  WordList(['3', 'PIECE', 'POLKADOT']),
#  WordList(['PIECE', 'POLKADOT', 'CUTLERY']),
#  WordList(['POLKADOT', 'CUTLERY', 'SET']),
#  WordList(['SET/6', 'RED', 'SPOTTY']),
#  WordList(['RED', 'SPOTTY', 'PAPER']),
#  WordList(['SPOTTY', 'PAPER', 'PLATES']),
#  WordList(['LUNCH', 'BAG', 'RED']),
#  WordList(['BAG', 'RED', 'RETROSPOT']),
#  WordList(['STRAWBERRY', 'LUNCH', 'BOX']),
#  WordList(['LUNCH', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'CUTLERY']),
#  WordList(['LUNCH', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'CUTLERY']),
#  WordList(['WITH', 'CUTLERY', 'RETROSPOT']),
#  WordList(['PACK', 'OF', '72']),
#  WordList(['OF', '72', 'RETROSPOT']),
#  WordList(['72', 'RETROSPOT', 'CAKE']),
#  WordList(['RETROSPOT', 'CAKE', 'CASES']),
#  WordList(['PACK', 'OF', '60']),
#  WordList(['OF', '60', 'DINOSAUR']),
#  WordList(['60', 'DINOSAUR', 'CAKE']),
#  WordList(['DINOSAUR', 'CAKE', 'CASES']),
#  WordList(['PACK', 'OF', '60']),
#  WordList(['OF', '60', 'PINK']),
#  WordList(['60', 'PINK', 'PAISLEY']),
#  WordList(['PINK', 'PAISLEY', 'CAKE']),
#  WordList(['PAISLEY', 'CAKE', 'CASES']),
#  WordList(['60', 'TEATIME', 'FAIRY']),
#  WordList(['TEATIME', 'FAIRY', 'CAKE']),
#  WordList(['FAIRY', 'CAKE', 'CASES']),
#  WordList(['TOMATO', 'CHARLIE+LOLA', 'COASTER']),
#  WordList(['CHARLIE+LOLA', 'COASTER', 'SET']),
#  WordList(['CHARLIE', 'LOLA', 'WASTEPAPER']),
#  WordList(['LOLA', 'WASTEPAPER', 'BIN']),
#  WordList(['WASTEPAPER', 'BIN', 'FLORA']),
#  WordList(['RED', 'CHARLIE+LOLA', 'PERSONAL']),
#  WordList(['CHARLIE+LOLA', 'PERSONAL', 'DOORSIGN']),
#  WordList(['JUMBO', 'STORAGE', 'BAG']),
#  WordList(['STORAGE', 'BAG', 'SUKI']),
#  WordList(['JUMBO', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'VINTAGE']),
#  WordList(['PINK', 'VINTAGE', 'PAISLEY']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'RED']),
#  WordList(['DISH', 'RED', 'RETROSPOT']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'BLUE']),
#  WordList(['DISH', 'BLUE', 'POLKADOT']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'PINK']),
#  WordList(['DISH', 'PINK', 'POLKADOT']),
#  WordList(['RECYCLING', 'BAG', 'RETROSPOT']),
#  WordList(['TOY', 'TIDY', 'PINK']),
#  WordList(['TIDY', 'PINK', 'POLKADOT']),
#  WordList(['JUMBO', 'BAG', 'RED']),
#  WordList(['BAG', 'RED', 'RETROSPOT']),
#  WordList(['SET/20', 'RED', 'RETROSPOT']),
#  WordList(['RED', 'RETROSPOT', 'PAPER']),
#  WordList(['RETROSPOT', 'PAPER', 'NAPKINS']),
#  WordList(['SET/6', 'RED', 'SPOTTY']),
#  WordList(['RED', 'SPOTTY', 'PAPER']),
#  WordList(['SPOTTY', 'PAPER', 'CUPS']),
#  WordList(['72', 'SWEETHEART', 'FAIRY']),
#  WordList(['SWEETHEART', 'FAIRY', 'CAKE']),
#  WordList(['FAIRY', 'CAKE', 'CASES']),
#  WordList(['SET', 'OF', '72']),
#  WordList(['OF', '72', 'RETROSPOT']),
#  WordList(['72', 'RETROSPOT', 'PAPER']),
#  WordList(['RETROSPOT', 'PAPER', 'DOILIES']),
#  WordList(['SET', 'OF', '36']),
#  WordList(['OF', '36', 'PAISLEY']),
#  WordList(['36', 'PAISLEY', 'FLOWER']),
#  WordList(['PAISLEY', 'FLOWER', 'DOILIES']),
#  WordList(['RECIPE', 'BOX', 'RETROSPOT']),
#  WordList(['CARROT', 'CHARLIE+LOLA', 'COASTER']),
#  WordList(['CHARLIE+LOLA', 'COASTER', 'SET']),
#  WordList(['SET', '3', 'RETROSPOT']),
#  WordList(['3', 'RETROSPOT', 'TEA']),
#  WordList(['RETROSPOT', 'TEA', 'COFFEE']),
#  WordList(['TEA', 'COFFEE', 'SUGAR']),
#  WordList(['SUKI', 'SHOULDER', 'BAG']),
#  WordList(['SKULL', 'SHOULDER', 'BAG']),
#  WordList(['GARDEN', 'METAL', 'SIGN']),
#  WordList(['SANDWICH', 'BATH', 'SPONGE']),
#  WordList(['A4', 'WALL', 'TIDY']),
#  WordList(['WALL', 'TIDY', 'RED']),
#  WordList(['TIDY', 'RED', 'FLOWERS']),
#  WordList(['CD', 'WALL', 'TIDY']),
#  WordList(['WALL', 'TIDY', 'RED']),
#  WordList(['TIDY', 'RED', 'FLOWERS']),
#  WordList(['PINK', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'PASSPORT']),
#  WordList(['JACK', 'PASSPORT', 'COVER']),
#  WordList(['PINK', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'LUGGAGE']),
#  WordList(['JACK', 'LUGGAGE', 'TAG']),
#  WordList(['UNION', 'JACK', 'FLAG']),
#  WordList(['JACK', 'FLAG', 'LUGGAGE']),
#  WordList(['FLAG', 'LUGGAGE', 'TAG']),
#  WordList(['SMALL', 'POP', 'BOX']),
#  WordList(['POP', 'BOX', 'FUNKY']),
#  WordList(['BOX', 'FUNKY', 'MONKEY']),
#  WordList(['UNION', 'JACK', 'FLAG']),
#  WordList(['JACK', 'FLAG', 'PASSPORT']),
#  WordList(['FLAG', 'PASSPORT', 'COVER']),
#  WordList(['DOORMAT', 'BLACK', 'FLOCK']),
#  WordList(['TOY', 'TIDY', 'SPACEBOY']),
#  WordList(['CHARLOTTE', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'POLKADOT']),
#  WordList(['SMALL', 'POPCORN', 'HOLDER']),
#  WordList(['RED', 'RETROSPOT', 'CHARLOTTE']),
#  WordList(['RETROSPOT', 'CHARLOTTE', 'BAG']),
#  WordList(['WOODLAND', 'CHARLOTTE', 'BAG']),
#  WordList(['CHARLOTTE', 'BAG', 'SUKI']),
#  WordList(['BAG', 'SUKI', 'DESIGN']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'SUKI']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'KEEP']),
#  WordList(['WALLET', 'KEEP', 'CALM']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'UNION']),
#  WordList(['WALLET', 'UNION', 'JACK']),
#  WordList(['ART', 'LIGHTS', 'FUNK']),
#  WordList(['LIGHTS', 'FUNK', 'MONKEY']),
#  WordList(['FUNKY', 'MONKEY', 'CUSHION']),
#  WordList(['MONKEY', 'CUSHION', 'COVER']),
#  WordList(['SCANDINAVIAN', 'PAISLEY', 'PICNIC']),
#  WordList(['PAISLEY', 'PICNIC', 'BAG']),
#  WordList(['STRAWBERRY', 'PICNIC', 'BAG']),
#  WordList(['BLUE', 'POLKADOT', 'BOWL']),
#  WordList(['RED', 'RETROSPOT', 'BOWL']),
#  WordList(['UNION', 'STRIPE', 'CUSHION']),
#  WordList(['STRIPE', 'CUSHION', 'COVER']),
#  WordList(['EMPIRE', 'DESIGN', 'ROSETTE']),
#  WordList(['UNION', 'FLAG', 'WINDSOCK']),
#  WordList(['SET/3', 'RED', 'GINGHAM']),
#  WordList(['RED', 'GINGHAM', 'ROSE']),
#  WordList(['GINGHAM', 'ROSE', 'STORAGE']),
#  WordList(['ROSE', 'STORAGE', 'BOX']),
#  WordList(['ELVIS', 'WALLHANGING', 'CURTAIN']),
#  WordList(['PINK', 'POLKADOT', 'CUP']),
#  WordList(['BLUE', 'POLKADOT', 'CUP']),
#  WordList(['RED', 'RETROSPOT', 'CUP']),
#  WordList(['RED', 'RETROSPOT', 'PLATE']),
#  WordList(['PACK', 'OF', '20']),
#  WordList(['OF', '20', 'SKULL']),
#  WordList(['20', 'SKULL', 'PAPER']),
#  WordList(['SKULL', 'PAPER', 'NAPKINS']),
#  WordList(['SET', '10', 'LIGHTS']),
#  WordList(['10', 'LIGHTS', 'NIGHT']),
#  WordList(['LIGHTS', 'NIGHT', 'OWL']),
#  WordList(['BIRTHDAY', 'PARTY', 'CORDON']),
#  WordList(['PARTY', 'CORDON', 'BARRIER']),
#  WordList(['CORDON', 'BARRIER', 'TAPE']),
#  WordList(['RED', 'RETROSPOT', 'PICNIC']),
#  WordList(['RETROSPOT', 'PICNIC', 'BAG']),
#  WordList(['PARTY', 'METAL', 'SIGN']),
#  WordList(['REX', 'CASH+CARRY', 'JUMBO']),
#  WordList(['CASH+CARRY', 'JUMBO', 'SHOPPER']),
#  WordList(['S/4', 'ICON', 'COASTER']),
#  WordList(['ICON', 'COASTER', 'ELVIS']),
#  WordList(['COASTER', 'ELVIS', 'LIVES']),
#  WordList(['OPEN', 'CLOSED', 'METAL']),
#  WordList(['CLOSED', 'METAL', 'SIGN']),
#  WordList(['PINK', 'POLKADOT', 'BOWL']),
#  WordList(['SMOKEY', 'GREY', 'COLOUR']),
#  WordList(['GREY', 'COLOUR', 'D.O.F']),
#  WordList(['COLOUR', 'D.O.F', 'GLASS']),
#  WordList(['JUNGLE', 'POPSICLES', 'ICE']),
#  WordList(['POPSICLES', 'ICE', 'LOLLY']),
#  WordList(['ICE', 'LOLLY', 'MOULDS']),
#  WordList(['CHARLOTTE', 'BAG', 'APPLES']),
#  WordList(['BAG', 'APPLES', 'DESIGN']),
#  WordList(['BEWARE', 'OF', 'THE']),
#  WordList(['OF', 'THE', 'CAT']),
#  WordList(['THE', 'CAT', 'METAL']),
#  WordList(['CAT', 'METAL', 'SIGN']),
#  WordList(['CHARLOTTE', 'BAG', 'VINTAGE']),
#  WordList(['BAG', 'VINTAGE', 'ALPHABET']),
#  WordList(['LAUNDRY', '15C', 'METAL']),
#  WordList(['15C', 'METAL', 'SIGN']),
#  WordList(['WASHROOM', 'METAL', 'SIGN']),
#  WordList(['FRENCH', 'TOILET', 'SIGN']),
#  WordList(['TOILET', 'SIGN', 'BLUE']),
#  WordList(['SIGN', 'BLUE', 'METAL']),
#  WordList(['JUMBO', 'BAG', 'APPLES']),
#  WordList(['JUMBO', 'BAG', 'ALPHABET']),
#  WordList(['LUNCH', 'BAG', 'BLACK']),
#  WordList(['BAG', 'BLACK', 'SKULL']),
#  WordList(['JUMBO', 'STORAGE', 'BAG']),
#  WordList(['STORAGE', 'BAG', 'SKULLS']),
#  WordList(['LUNCH', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'POLKADOT']),
#  WordList(['LUNCH', 'BAG', 'CARS']),
#  WordList(['BAG', 'CARS', 'BLUE']),
#  WordList(['TOXIC', 'AREA', 'DOOR']),
#  WordList(['AREA', 'DOOR', 'HANGER']),
#  WordList(['DO', 'NOT', 'TOUCH']),
#  WordList(['NOT', 'TOUCH', 'MY']),
#  WordList(['TOUCH', 'MY', 'STUFF']),
#  WordList(['MY', 'STUFF', 'DOOR']),
#  WordList(['STUFF', 'DOOR', 'HANGER']),
#  WordList(['SMALL', 'WHITE', 'HEART']),
#  WordList(['WHITE', 'HEART', 'OF']),
#  WordList(['HEART', 'OF', 'WICKER']),
#  WordList(['RED', 'METAL', 'BOX']),
#  WordList(['METAL', 'BOX', 'TOP']),
#  WordList(['BOX', 'TOP', 'SECRET']),
#  WordList(['JUMBO', 'BAG', 'STRAWBERRY']),
#  WordList(['SMALL', 'POP', 'BOX']),
#  WordList(['POP', 'BOX', 'FUNKY']),
#  WordList(['BOX', 'FUNKY', 'MONKEY']),
#  WordList(['GARAGE', 'KEY', 'FOB']),
#  WordList(['SKULL', 'LUNCH', 'BOX']),
#  WordList(['LUNCH', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'CUTLERY']),
#  WordList(['JUMBO', 'BAG', 'TOYS']),
#  WordList(['GUMBALL', 'COAT', 'RACK']),
#  WordList(['CHILDRENS', 'TOY', 'COOKING']),
#  WordList(['TOY', 'COOKING', 'UTENSIL']),
#  WordList(['COOKING', 'UTENSIL', 'SET']),
#  WordList(['BAKING', 'SET', '9']),
#  WordList(['SET', '9', 'PIECE']),
#  WordList(['9', 'PIECE', 'RETROSPOT']),
#  WordList(['SKULLS', 'STORAGE', 'BOX']),
#  WordList(['STORAGE', 'BOX', 'SMALL']),
#  WordList(['BAKING', 'SET', 'SPACEBOY']),
#  WordList(['SET', 'SPACEBOY', 'DESIGN']),
#  WordList(['BOTANICAL', 'GARDENS', 'WALL']),
#  WordList(['GARDENS', 'WALL', 'CLOCK']),
#  WordList(['SET', '6', 'SCHOOL']),
#  WordList(['6', 'SCHOOL', 'MILK']),
#  WordList(['SCHOOL', 'MILK', 'BOTTLES']),
#  WordList(['MILK', 'BOTTLES', 'IN']),
#  WordList(['BOTTLES', 'IN', 'CRATE']),
#  WordList(['LARGE', 'ROUND', 'WICKER']),
#  WordList(['ROUND', 'WICKER', 'PLATTER']),
#  WordList(['GARDENERS', 'KNEELING', 'PAD']),
#  WordList(['KNEELING', 'PAD', 'KEEP']),
#  WordList(['PAD', 'KEEP', 'CALM']),
#  WordList(['CLASSIC', 'GLASS', 'COOKIE']),
#  WordList(['GLASS', 'COOKIE', 'JAR']),
#  WordList(['LUNCH', 'BAG', 'PAISLEY']),
#  WordList(['BAG', 'PAISLEY', 'PARK']),
#  WordList(['SWIRLY', 'CIRCULAR', 'RUBBERS']),
#  WordList(['CIRCULAR', 'RUBBERS', 'IN']),
#  WordList(['RUBBERS', 'IN', 'BAG']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'STRAWBERRY']),
#  WordList(['6', 'STRAWBERRY', 'CHOPSTICKS']),
#  WordList(['GYMKHANA', 'TREASURE', 'BOOK']),
#  WordList(['TREASURE', 'BOOK', 'BOX']),
#  WordList(['TREASURE', 'TIN', 'GYMKHANA']),
#  WordList(['TIN', 'GYMKHANA', 'DESIGN']),
#  WordList(['SIX', 'DRAWER', 'OFFICE']),
#  WordList(['DRAWER', 'OFFICE', 'TIDY']),
#  WordList(['KEY', 'RING', 'BASEBALL']),
#  WordList(['RING', 'BASEBALL', 'BOOT']),
#  WordList(['BASEBALL', 'BOOT', 'UNION']),
#  WordList(['BOOT', 'UNION', 'JACK']),
#  WordList(['KITTY', 'PENCIL', 'ERASERS']),
#  WordList(['SLEEPING', 'CAT', 'ERASERS']),
#  WordList(['BICYCLE', 'PUNCTURE', 'REPAIR']),
#  WordList(['PUNCTURE', 'REPAIR', 'KIT']),
#  WordList(['BLUE', 'CALCULATOR', 'RULER']),
#  WordList(['TRADITIONAL', 'NAUGHTS', 'CROSSES']),
#  WordList(['PACK', 'OF', '12']),
#  WordList(['OF', '12', 'COLOURED']),
#  WordList(['12', 'COLOURED', 'PENCILS']),
#  WordList(['FELTCRAFT', 'GIRL', 'NICOLE']),
#  WordList(['GIRL', 'NICOLE', 'KIT']),
#  WordList(['SKULL', 'DESIGN', 'TV']),
#  WordList(['DESIGN', 'TV', 'DINNER']),
#  WordList(['TV', 'DINNER', 'TRAY']),
#  WordList(['IVORY', 'DINER', 'WALL']),
#  WordList(['DINER', 'WALL', 'CLOCK']),
#  WordList(['12', 'PENCILS', 'TALL']),
#  WordList(['PENCILS', 'TALL', 'TUBE']),
#  WordList(['TALL', 'TUBE', 'SKULLS']),
#  WordList(['RED', 'DRAGONFLY', 'HELICOPTER']),
#  WordList(['YELLOW', 'SHARK', 'HELICOPTER']),
#  WordList(['BUNDLE', 'OF', '3']),
#  WordList(['OF', '3', 'ALPHABET']),
#  WordList(['3', 'ALPHABET', 'EXERCISE']),
#  WordList(['ALPHABET', 'EXERCISE', 'BOOKS']),
#  WordList(['JUMBO', 'BAG', 'PAISLEY']),
#  WordList(['BAG', 'PAISLEY', 'PARK']),
#  WordList(['CHRISTMAS', 'LIGHTS', '10']),
#  WordList(['LIGHTS', '10', 'VINTAGE']),
#  WordList(['10', 'VINTAGE', 'BAUBLES']),
#  WordList(['FELTCRAFT', 'CUSHION', 'BUTTERFLY']),
#  WordList(['FELTCRAFT', 'CUSHION', 'OWL']),
#  WordList(['CHARLIE', 'LOLA', 'RED']),
#  WordList(['LOLA', 'RED', 'HOT']),
#  WordList(['RED', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['CHARLIE+LOLA', 'PINK', 'HOT']),
#  WordList(['PINK', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['FELTCRAFT', 'CHRISTMAS', 'FAIRY']),
#  WordList(['SET', 'OF', '20']),
#  WordList(['OF', '20', 'VINTAGE']),
#  WordList(['20', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['VINTAGE', 'CHRISTMAS', 'NAPKINS']),
#  WordList(['TRAVEL', 'SEWING', 'KIT']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', 'VINTAGE']),
#  WordList(['KIT', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['IVORY', 'KITCHEN', 'SCALES']),
#  WordList(['DOORMAT', 'KEEP', 'CALM']),
#  WordList(['KEEP', 'CALM', 'AND']),
#  WordList(['CALM', 'AND', 'COME']),
#  WordList(['AND', 'COME', 'IN']),
#  WordList(['SOLDIERS', 'EGG', 'CUP']),
#  WordList(['MIRRORED', 'DISCO', 'BALL']),
#  WordList(['DISCO', 'BALL', 'ROTATOR']),
#  WordList(['BALL', 'ROTATOR', 'BATTERY']),
#  WordList(['ROTATOR', 'BATTERY', 'OPERATED']),
#  WordList(['DINOSAUR', 'PARTY', 'BAG']),
#  WordList(['PARTY', 'BAG', 'STICKER']),
#  WordList(['BAG', 'STICKER', 'SET']),
#  WordList(['RETROSPOT', 'PARTY', 'BAG']),
#  WordList(['PARTY', 'BAG', 'STICKER']),
#  WordList(['BAG', 'STICKER', 'SET']),
#  WordList(['RECYCLED', 'PENCIL', 'WITH']),
#  WordList(['PENCIL', 'WITH', 'RABBIT']),
#  WordList(['WITH', 'RABBIT', 'ERASER']),
#  WordList(['6', 'ROCKET', 'BALLOONS']),
#  WordList(['BLUE', 'HARMONICA', 'IN']),
#  WordList(['HARMONICA', 'IN', 'BOX']),
#  WordList(['SET/4', 'BADGES', 'DOGS']),
#  WordList(['DINOSAURS', 'WRITING', 'SET']),
#  WordList(['12', 'PENCILS', 'SMALL']),
#  WordList(['PENCILS', 'SMALL', 'TUBE']),
#  WordList(['SMALL', 'TUBE', 'SKULL']),
#  WordList(['DINOSAUR', 'KEYRINGS', 'ASSORTED']),
#  WordList(['BOX', 'OF', '6']),
#  WordList(['OF', '6', 'CHRISTMAS']),
#  WordList(['6', 'CHRISTMAS', 'CAKE']),
#  WordList(['CHRISTMAS', 'CAKE', 'DECORATIONS']),
#  WordList(['CHRISTMAS', 'CRAFT', 'TREE']),
#  WordList(['CRAFT', 'TREE', 'TOP']),
#  WordList(['TREE', 'TOP', 'ANGEL']),
#  WordList(['CHRISTMAS', 'CRAFT', 'WHITE']),
#  WordList(['CRAFT', 'WHITE', 'FAIRY']),
#  WordList(['VINTAGE', 'CHRISTMAS', 'GIFT']),
#  WordList(['CHRISTMAS', 'GIFT', 'SACK']),
#  WordList(['WOODEN', 'SCHOOL', 'COLOURING']),
#  WordList(['SCHOOL', 'COLOURING', 'SET']),
#  WordList(['VINTAGE', '2', 'METER']),
#  WordList(['2', 'METER', 'FOLDING']),
#  WordList(['METER', 'FOLDING', 'RULER']),
#  WordList(['GIRAFFE', 'WOODEN', 'RULER']),
#  WordList(['REVOLVER', 'WOODEN', 'RULER']),
#  WordList(['BOX', 'OF', '24']),
#  WordList(['OF', '24', 'COCKTAIL']),
#  WordList(['24', 'COCKTAIL', 'PARASOLS']),
#  WordList(['GARDENERS', 'KNEELING', 'PAD']),
#  WordList(['KNEELING', 'PAD', 'CUP']),
#  WordList(['PAD', 'CUP', 'OF']),
#  WordList(['CUP', 'OF', 'TEA']),
#  WordList(['ROTATING', 'SILVER', 'ANGELS']),
#  WordList(['SILVER', 'ANGELS', 'T-LIGHT']),
#  WordList(['ANGELS', 'T-LIGHT', 'HLDR']),
#  WordList(['VINTAGE', '2', 'METRE']),
#  WordList(['2', 'METRE', 'FOLDING']),
#  WordList(['METRE', 'FOLDING', 'RULER']),
#  WordList(['RETROSPOT', 'TEA', 'SET']),
#  WordList(['TEA', 'SET', 'CERAMIC']),
#  WordList(['SET', 'CERAMIC', '11']),
#  WordList(['CERAMIC', '11', 'PC']),
#  WordList(['GIRLY', 'PINK', 'TOOL']),
#  WordList(['PINK', 'TOOL', 'SET']),
#  WordList(['AIRLINE', 'LOUNGE', 'METAL']),
#  WordList(['LOUNGE', 'METAL', 'SIGN']),
#  WordList(['RED', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'ACRYLIC']),
#  WordList(['KNOB', 'ACRYLIC', 'EDWARDIAN']),
#  WordList(['CLEAR', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'ACRYLIC']),
#  WordList(['KNOB', 'ACRYLIC', 'EDWARDIAN']),
#  WordList(['PHOTO', 'CLIP', 'LINE']),
#  WordList(['FELT', 'EGG', 'COSY']),
#  WordList(['EGG', 'COSY', 'CHICKEN']),
#  WordList(['PIGGY', 'BANK', 'RETROSPOT']),
#  WordList(['COOK', 'WITH', 'WINE']),
#  WordList(['WITH', 'WINE', 'METAL']),
#  WordList(['WINE', 'METAL', 'SIGN']),
#  WordList(['GIN', 'TONIC', 'DIET']),
#  WordList(['TONIC', 'DIET', 'METAL']),
#  WordList(['DIET', 'METAL', 'SIGN']),
#  WordList(['YELLOW', 'BREAKFAST', 'CUP']),
#  WordList(['BREAKFAST', 'CUP', 'AND']),
#  WordList(['CUP', 'AND', 'SAUCER']),
#  WordList(['PINK', 'BREAKFAST', 'CUP']),
#  WordList(['BREAKFAST', 'CUP', 'AND']),
#  WordList(['CUP', 'AND', 'SAUCER']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', 'RETROSPOT']),
#  WordList(['SMALL', 'HEART', 'FLOWERS']),
#  WordList(['HEART', 'FLOWERS', 'HOOK']),
#  WordList(['TEA', 'TIME', 'DES']),
#  WordList(['TIME', 'DES', 'TEA']),
#  WordList(['DES', 'TEA', 'COSY']),
#  WordList(['FELT', 'EGG', 'COSY']),
#  WordList(['EGG', 'COSY', 'WHITE']),
#  WordList(['COSY', 'WHITE', 'RABBIT']),
#  WordList(['ZINC', 'WILLIE', 'WINKIE']),
#  WordList(['WILLIE', 'WINKIE', 'CANDLE']),
#  WordList(['WINKIE', 'CANDLE', 'STICK']),
#  WordList(['CERAMIC', 'CHERRY', 'CAKE']),
#  WordList(['CHERRY', 'CAKE', 'MONEY']),
#  WordList(['CAKE', 'MONEY', 'BANK']),
#  WordList(['RETROSPOT', 'LARGE', 'MILK']),
#  WordList(['LARGE', 'MILK', 'JUG']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'FUNKY']),
#  WordList(['6', 'FUNKY', 'BEAKERS']),
#  WordList(['EDWARDIAN', 'PARASOL', 'NATURAL']),
#  WordList(['CERAMIC', 'STRAWBERRY', 'CAKE']),
#  WordList(['STRAWBERRY', 'CAKE', 'MONEY']),
#  WordList(['CAKE', 'MONEY', 'BANK']),
#  WordList(['BLUE', 'OWL', 'SOFT']),
#  WordList(['OWL', 'SOFT', 'TOY']),
#  WordList(['BALLOON', 'ART', 'MAKE']),
#  WordList(['ART', 'MAKE', 'YOUR']),
#  WordList(['MAKE', 'YOUR', 'OWN']),
#  WordList(['YOUR', 'OWN', 'FLOWERS']),
#  WordList(['RED', 'TOADSTOOL', 'LED']),
#  WordList(['TOADSTOOL', 'LED', 'NIGHT']),
#  WordList(['LED', 'NIGHT', 'LIGHT']),
#  WordList(['GLASS', 'CLOCHE', 'SMALL']),
#  WordList(['GUMBALL', 'MONOCHROME', 'COAT']),
#  WordList(['MONOCHROME', 'COAT', 'RACK']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'COLOURED']),
#  WordList(['3', 'COLOURED', 'FLYING']),
#  WordList(['COLOURED', 'FLYING', 'DUCKS']),
#  WordList(['4', 'TRADITIONAL', 'SPINNING']),
#  WordList(['TRADITIONAL', 'SPINNING', 'TOPS']),
#  WordList(['ANTIQUE', 'SILVER', 'TEA']),
#  WordList(['SILVER', 'TEA', 'GLASS']),
#  WordList(['TEA', 'GLASS', 'ETCHED']),
#  WordList(['NEW', 'BAROQUE', 'BLACK']),
#  WordList(['BAROQUE', 'BLACK', 'PHOTO']),
#  WordList(['BLACK', 'PHOTO', 'ALBUM']),
#  WordList(['SKULLS', 'GREETING', 'CARD']),
#  WordList(['PINK', 'WHITE', 'BREAKFAST']),
#  WordList(['WHITE', 'BREAKFAST', 'TRAY']),
#  WordList(['BLUE', 'WHITE', 'BREAKFAST']),
#  WordList(['WHITE', 'BREAKFAST', 'TRAY']),
#  WordList(['PICNIC', 'BASKET', 'WICKER']),
#  WordList(['BASKET', 'WICKER', 'SMALL']),
#  WordList(['PURPLE', 'DRAWERKNOB', 'ACRYLIC']),
#  WordList(['DRAWERKNOB', 'ACRYLIC', 'EDWARDIAN']),
#  WordList(['CHOCOLATE', '3', 'WICK']),
#  WordList(['3', 'WICK', 'MORRIS']),
#  WordList(['WICK', 'MORRIS', 'BOX']),
#  WordList(['MORRIS', 'BOX', 'CANDLE']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'HEART']),
#  WordList(['3', 'HEART', 'COOKIE']),
#  WordList(['HEART', 'COOKIE', 'CUTTERS']),
#  WordList(['TEA', 'FOR', 'ONE']),
#  WordList(['FOR', 'ONE', 'POLKADOT']),
#  WordList(['METAL', 'SIGN', 'CUPCAKE']),
#  WordList(['SIGN', 'CUPCAKE', 'SINGLE']),
#  WordList(['CUPCAKE', 'SINGLE', 'HOOK']),
#  WordList(['FANNY', "'S", 'REST']),
#  WordList(["'S", 'REST', 'STOPMETAL']),
#  WordList(['REST', 'STOPMETAL', 'SIGN']),
#  WordList(['MOODY', 'GIRL', 'DOOR']),
#  WordList(['GIRL', 'DOOR', 'HANGER']),
#  WordList(['BLACK/BLUE', 'POLKADOT', 'UMBRELLA']),
#  WordList(['MINI', 'CAKE', 'STAND']),
#  WordList(['CAKE', 'STAND', 'WITH']),
#  WordList(['STAND', 'WITH', 'HANGING']),
#  WordList(['WITH', 'HANGING', 'CAKES']),
#  WordList(['CERAMIC', 'CAKE', 'STAND']),
#  WordList(['CAKE', 'STAND', 'HANGING']),
#  WordList(['STAND', 'HANGING', 'CAKES']),
#  WordList(['WHITE', 'BAMBOO', 'RIBS']),
#  WordList(['BAMBOO', 'RIBS', 'LAMPSHADE']),
#  WordList(['WHITE', 'BEADED', 'GARLAND']),
#  WordList(['BEADED', 'GARLAND', 'STRING']),
#  WordList(['GARLAND', 'STRING', '20LIGHT']),
#  WordList(['CLEAR', 'MILKSHAKE', 'GLASS']),
#  WordList(['LARGE', 'POPCORN', 'HOLDER']),
#  WordList(['GLITTER', 'HANGING', 'BUTTERFLY']),
#  WordList(['HANGING', 'BUTTERFLY', 'STRING']),
#  WordList(['ROCKING', 'HORSE', 'RED']),
#  WordList(['HORSE', 'RED', 'CHRISTMAS']),
#  WordList(['3D', 'SHEET', 'OF']),
#  WordList(['SHEET', 'OF', 'CAT']),
#  WordList(['OF', 'CAT', 'STICKERS']),
#  WordList(['PINK', '3', 'PIECE']),
#  WordList(['3', 'PIECE', 'POLKADOT']),
#  WordList(['PIECE', 'POLKADOT', 'CUTLERY']),
#  WordList(['POLKADOT', 'CUTLERY', 'SET']),
#  WordList(['BLUE', 'FLOCK', 'CUSHION']),
#  WordList(['FLOCK', 'CUSHION', 'COVER']),
#  ...]

# %%
blob = TextBlob(w)

blob.ngrams(n=3)
# Out:
# [WordList(['WHITE', 'HANGING', 'HEART']),
#  WordList(['HANGING', 'HEART', 'T-LIGHT']),
#  WordList(['HEART', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'WHITE']),
#  WordList(['HOLDER', 'WHITE', 'METAL']),
#  WordList(['WHITE', 'METAL', 'LANTERN']),
#  WordList(['METAL', 'LANTERN', 'CREAM']),
#  WordList(['LANTERN', 'CREAM', 'CUPID']),
#  WordList(['CREAM', 'CUPID', 'HEARTS']),
#  WordList(['CUPID', 'HEARTS', 'COAT']),
#  WordList(['HEARTS', 'COAT', 'HANGER']),
#  WordList(['COAT', 'HANGER', 'KNITTED']),
#  WordList(['HANGER', 'KNITTED', 'UNION']),
#  WordList(['KNITTED', 'UNION', 'FLAG']),
#  WordList(['UNION', 'FLAG', 'HOT']),
#  WordList(['FLAG', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'RED']),
#  WordList(['BOTTLE', 'RED', 'WOOLLY']),
#  WordList(['RED', 'WOOLLY', 'HOTTIE']),
#  WordList(['WOOLLY', 'HOTTIE', 'WHITE']),
#  WordList(['HOTTIE', 'WHITE', 'HEART']),
#  WordList(['WHITE', 'HEART', 'SET']),
#  WordList(['HEART', 'SET', '7']),
#  WordList(['SET', '7', 'BABUSHKA']),
#  WordList(['7', 'BABUSHKA', 'NESTING']),
#  WordList(['BABUSHKA', 'NESTING', 'BOXES']),
#  WordList(['NESTING', 'BOXES', 'GLASS']),
#  WordList(['BOXES', 'GLASS', 'STAR']),
#  WordList(['GLASS', 'STAR', 'FROSTED']),
#  WordList(['STAR', 'FROSTED', 'T-LIGHT']),
#  WordList(['FROSTED', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'HAND']),
#  WordList(['HOLDER', 'HAND', 'WARMER']),
#  WordList(['HAND', 'WARMER', 'UNION']),
#  WordList(['WARMER', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'HAND']),
#  WordList(['JACK', 'HAND', 'WARMER']),
#  WordList(['HAND', 'WARMER', 'RED']),
#  WordList(['WARMER', 'RED', 'POLKA']),
#  WordList(['RED', 'POLKA', 'DOT']),
#  WordList(['POLKA', 'DOT', 'EDWARDIAN']),
#  WordList(['DOT', 'EDWARDIAN', 'PARASOL']),
#  WordList(['EDWARDIAN', 'PARASOL', 'RED']),
#  WordList(['PARASOL', 'RED', 'RETRO']),
#  WordList(['RED', 'RETRO', 'COFFEE']),
#  WordList(['RETRO', 'COFFEE', 'MUGS']),
#  WordList(['COFFEE', 'MUGS', 'ASSORTED']),
#  WordList(['MUGS', 'ASSORTED', 'SAVE']),
#  WordList(['ASSORTED', 'SAVE', 'THE']),
#  WordList(['SAVE', 'THE', 'PLANET']),
#  WordList(['THE', 'PLANET', 'MUG']),
#  WordList(['PLANET', 'MUG', 'VINTAGE']),
#  WordList(['MUG', 'VINTAGE', 'BILLBOARD']),
#  WordList(['VINTAGE', 'BILLBOARD', 'DRINK']),
#  WordList(['BILLBOARD', 'DRINK', 'ME']),
#  WordList(['DRINK', 'ME', 'MUG']),
#  WordList(['ME', 'MUG', 'VINTAGE']),
#  WordList(['MUG', 'VINTAGE', 'BILLBOARD']),
#  WordList(['VINTAGE', 'BILLBOARD', 'LOVE/HATE']),
#  WordList(['BILLBOARD', 'LOVE/HATE', 'MUG']),
#  WordList(['LOVE/HATE', 'MUG', 'WOOD']),
#  WordList(['MUG', 'WOOD', '2']),
#  WordList(['WOOD', '2', 'DRAWER']),
#  WordList(['2', 'DRAWER', 'CABINET']),
#  WordList(['DRAWER', 'CABINET', 'WHITE']),
#  WordList(['CABINET', 'WHITE', 'FINISH']),
#  WordList(['WHITE', 'FINISH', 'WOOD']),
#  WordList(['FINISH', 'WOOD', 'S/3']),
#  WordList(['WOOD', 'S/3', 'CABINET']),
#  WordList(['S/3', 'CABINET', 'ANT']),
#  WordList(['CABINET', 'ANT', 'WHITE']),
#  WordList(['ANT', 'WHITE', 'FINISH']),
#  WordList(['WHITE', 'FINISH', 'WOODEN']),
#  WordList(['FINISH', 'WOODEN', 'PICTURE']),
#  WordList(['WOODEN', 'PICTURE', 'FRAME']),
#  WordList(['PICTURE', 'FRAME', 'WHITE']),
#  WordList(['FRAME', 'WHITE', 'FINISH']),
#  WordList(['WHITE', 'FINISH', 'WOODEN']),
#  WordList(['FINISH', 'WOODEN', 'FRAME']),
#  WordList(['WOODEN', 'FRAME', 'ANTIQUE']),
#  WordList(['FRAME', 'ANTIQUE', 'WHITE']),
#  WordList(['ANTIQUE', 'WHITE', 'EDWARDIAN']),
#  WordList(['WHITE', 'EDWARDIAN', 'PARASOL']),
#  WordList(['EDWARDIAN', 'PARASOL', 'BLACK']),
#  WordList(['PARASOL', 'BLACK', 'IVORY']),
#  WordList(['BLACK', 'IVORY', 'EMBROIDERED']),
#  WordList(['IVORY', 'EMBROIDERED', 'QUILT']),
#  WordList(['EMBROIDERED', 'QUILT', 'JUMBO']),
#  WordList(['QUILT', 'JUMBO', 'SHOPPER']),
#  WordList(['JUMBO', 'SHOPPER', 'VINTAGE']),
#  WordList(['SHOPPER', 'VINTAGE', 'RED']),
#  WordList(['VINTAGE', 'RED', 'PAISLEY']),
#  WordList(['RED', 'PAISLEY', 'HAND']),
#  WordList(['PAISLEY', 'HAND', 'WARMER']),
#  WordList(['HAND', 'WARMER', 'RED']),
#  WordList(['WARMER', 'RED', 'RETROSPOT']),
#  WordList(['RED', 'RETROSPOT', 'GIN']),
#  WordList(['RETROSPOT', 'GIN', 'AND']),
#  WordList(['GIN', 'AND', 'TONIC']),
#  WordList(['AND', 'TONIC', 'MUG']),
#  WordList(['TONIC', 'MUG', 'COLOUR']),
#  WordList(['MUG', 'COLOUR', 'GLASS']),
#  WordList(['COLOUR', 'GLASS', 'STAR']),
#  WordList(['GLASS', 'STAR', 'T-LIGHT']),
#  WordList(['STAR', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'YOU']),
#  WordList(['HOLDER', 'YOU', "'RE"]),
#  WordList(['YOU', "'RE", 'CONFUSING']),
#  WordList(["'RE", 'CONFUSING', 'ME']),
#  WordList(['CONFUSING', 'ME', 'METAL']),
#  WordList(['ME', 'METAL', 'SIGN']),
#  WordList(['METAL', 'SIGN', 'ASSORTED']),
#  WordList(['SIGN', 'ASSORTED', 'COLOUR']),
#  WordList(['ASSORTED', 'COLOUR', 'BIRD']),
#  WordList(['COLOUR', 'BIRD', 'ORNAMENT']),
#  WordList(['BIRD', 'ORNAMENT', 'POPPY']),
#  WordList(['ORNAMENT', 'POPPY', "'S"]),
#  WordList(['POPPY', "'S", 'PLAYHOUSE']),
#  WordList(["'S", 'PLAYHOUSE', 'BEDROOM']),
#  WordList(['PLAYHOUSE', 'BEDROOM', 'POPPY']),
#  WordList(['BEDROOM', 'POPPY', "'S"]),
#  WordList(['POPPY', "'S", 'PLAYHOUSE']),
#  WordList(["'S", 'PLAYHOUSE', 'KITCHEN']),
#  WordList(['PLAYHOUSE', 'KITCHEN', 'FELTCRAFT']),
#  WordList(['KITCHEN', 'FELTCRAFT', 'PRINCESS']),
#  WordList(['FELTCRAFT', 'PRINCESS', 'CHARLOTTE']),
#  WordList(['PRINCESS', 'CHARLOTTE', 'DOLL']),
#  WordList(['CHARLOTTE', 'DOLL', 'IVORY']),
#  WordList(['DOLL', 'IVORY', 'KNITTED']),
#  WordList(['IVORY', 'KNITTED', 'MUG']),
#  WordList(['KNITTED', 'MUG', 'COSY']),
#  WordList(['MUG', 'COSY', 'BOX']),
#  WordList(['COSY', 'BOX', 'OF']),
#  WordList(['BOX', 'OF', '6']),
#  WordList(['OF', '6', 'ASSORTED']),
#  WordList(['6', 'ASSORTED', 'COLOUR']),
#  WordList(['ASSORTED', 'COLOUR', 'TEASPOONS']),
#  WordList(['COLOUR', 'TEASPOONS', 'BOX']),
#  WordList(['TEASPOONS', 'BOX', 'OF']),
#  WordList(['BOX', 'OF', 'VINTAGE']),
#  WordList(['OF', 'VINTAGE', 'JIGSAW']),
#  WordList(['VINTAGE', 'JIGSAW', 'BLOCKS']),
#  WordList(['JIGSAW', 'BLOCKS', 'BOX']),
#  WordList(['BLOCKS', 'BOX', 'OF']),
#  WordList(['BOX', 'OF', 'VINTAGE']),
#  WordList(['OF', 'VINTAGE', 'ALPHABET']),
#  WordList(['VINTAGE', 'ALPHABET', 'BLOCKS']),
#  WordList(['ALPHABET', 'BLOCKS', 'HOME']),
#  WordList(['BLOCKS', 'HOME', 'BUILDING']),
#  WordList(['HOME', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['BLOCK', 'WORD', 'LOVE']),
#  WordList(['WORD', 'LOVE', 'BUILDING']),
#  WordList(['LOVE', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['BLOCK', 'WORD', 'RECIPE']),
#  WordList(['WORD', 'RECIPE', 'BOX']),
#  WordList(['RECIPE', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'METAL']),
#  WordList(['WITH', 'METAL', 'HEART']),
#  WordList(['METAL', 'HEART', 'DOORMAT']),
#  WordList(['HEART', 'DOORMAT', 'NEW']),
#  WordList(['DOORMAT', 'NEW', 'ENGLAND']),
#  WordList(['NEW', 'ENGLAND', 'JAM']),
#  WordList(['ENGLAND', 'JAM', 'MAKING']),
#  WordList(['JAM', 'MAKING', 'SET']),
#  WordList(['MAKING', 'SET', 'WITH']),
#  WordList(['SET', 'WITH', 'JARS']),
#  WordList(['WITH', 'JARS', 'RED']),
#  WordList(['JARS', 'RED', 'COAT']),
#  WordList(['RED', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['PARIS', 'FASHION', 'YELLOW']),
#  WordList(['FASHION', 'YELLOW', 'COAT']),
#  WordList(['YELLOW', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['PARIS', 'FASHION', 'BLUE']),
#  WordList(['FASHION', 'BLUE', 'COAT']),
#  WordList(['BLUE', 'COAT', 'RACK']),
#  WordList(['COAT', 'RACK', 'PARIS']),
#  WordList(['RACK', 'PARIS', 'FASHION']),
#  WordList(['PARIS', 'FASHION', 'BATH']),
#  WordList(['FASHION', 'BATH', 'BUILDING']),
#  WordList(['BATH', 'BUILDING', 'BLOCK']),
#  WordList(['BUILDING', 'BLOCK', 'WORD']),
#  WordList(['BLOCK', 'WORD', 'FELTCRAFT']),
#  WordList(['WORD', 'FELTCRAFT', 'DOLL']),
#  WordList(['FELTCRAFT', 'DOLL', 'EMILY']),
#  WordList(['DOLL', 'EMILY', 'WRAP']),
#  WordList(['EMILY', 'WRAP', 'ENGLISH']),
#  WordList(['WRAP', 'ENGLISH', 'ROSE']),
#  WordList(['ENGLISH', 'ROSE', 'PHOTO']),
#  WordList(['ROSE', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'CORNICE']),
#  WordList(['FRAME', 'CORNICE', 'WRAP']),
#  WordList(['CORNICE', 'WRAP', 'DOLLY']),
#  WordList(['WRAP', 'DOLLY', 'GIRL']),
#  WordList(['DOLLY', 'GIRL', 'WRAP']),
#  WordList(['GIRL', 'WRAP', 'DOILEY']),
#  WordList(['WRAP', 'DOILEY', 'DESIGN']),
#  WordList(['DOILEY', 'DESIGN', 'SET']),
#  WordList(['DESIGN', 'SET', 'OF']),
#  WordList(['SET', 'OF', '12']),
#  WordList(['OF', '12', 'VINTAGE']),
#  WordList(['12', 'VINTAGE', 'POSTCARD']),
#  WordList(['VINTAGE', 'POSTCARD', 'SET']),
#  WordList(['POSTCARD', 'SET', 'SET']),
#  WordList(['SET', 'SET', 'OF']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'VINTAGE']),
#  WordList(['6', 'VINTAGE', 'NOTELETS']),
#  WordList(['VINTAGE', 'NOTELETS', 'KIT']),
#  WordList(['NOTELETS', 'KIT', 'SWEETHEART']),
#  WordList(['KIT', 'SWEETHEART', 'WIRE']),
#  WordList(['SWEETHEART', 'WIRE', 'WALL']),
#  WordList(['WIRE', 'WALL', 'TIDY']),
#  WordList(['WALL', 'TIDY', 'SET']),
#  WordList(['TIDY', 'SET', 'OF']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'SPICE']),
#  WordList(['6', 'SPICE', 'TINS']),
#  WordList(['SPICE', 'TINS', 'PANTRY']),
#  WordList(['TINS', 'PANTRY', 'DESIGN']),
#  WordList(['PANTRY', 'DESIGN', 'JAM']),
#  WordList(['DESIGN', 'JAM', 'MAKING']),
#  WordList(['JAM', 'MAKING', 'SET']),
#  WordList(['MAKING', 'SET', 'PRINTED']),
#  WordList(['SET', 'PRINTED', 'HOMEMADE']),
#  WordList(['PRINTED', 'HOMEMADE', 'JAM']),
#  WordList(['HOMEMADE', 'JAM', 'SCENTED']),
#  WordList(['JAM', 'SCENTED', 'CANDLES']),
#  WordList(['SCENTED', 'CANDLES', 'SET']),
#  WordList(['CANDLES', 'SET', 'OF']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'CAKE']),
#  WordList(['3', 'CAKE', 'TINS']),
#  WordList(['CAKE', 'TINS', 'PANTRY']),
#  WordList(['TINS', 'PANTRY', 'DESIGN']),
#  WordList(['PANTRY', 'DESIGN', 'PICTURE']),
#  WordList(['DESIGN', 'PICTURE', 'DOMINOES']),
#  WordList(['PICTURE', 'DOMINOES', 'PINK']),
#  WordList(['DOMINOES', 'PINK', 'CREAM']),
#  WordList(['PINK', 'CREAM', 'FELT']),
#  WordList(['CREAM', 'FELT', 'CRAFT']),
#  WordList(['FELT', 'CRAFT', 'TRINKET']),
#  WordList(['CRAFT', 'TRINKET', 'BOX']),
#  WordList(['TRINKET', 'BOX', 'MAKE']),
#  WordList(['BOX', 'MAKE', 'YOUR']),
#  WordList(['MAKE', 'YOUR', 'OWN']),
#  WordList(['YOUR', 'OWN', 'FLOWERPOWER']),
#  WordList(['OWN', 'FLOWERPOWER', 'CARD']),
#  WordList(['FLOWERPOWER', 'CARD', 'KIT']),
#  WordList(['CARD', 'KIT', 'GLASS']),
#  WordList(['KIT', 'GLASS', 'BEURRE']),
#  WordList(['GLASS', 'BEURRE', 'DISH']),
#  WordList(['BEURRE', 'DISH', 'DOORMAT']),
#  WordList(['DISH', 'DOORMAT', 'ENGLISH']),
#  WordList(['DOORMAT', 'ENGLISH', 'ROSE']),
#  WordList(['ENGLISH', 'ROSE', 'DOORMAT']),
#  WordList(['ROSE', 'DOORMAT', 'WELCOME']),
#  WordList(['DOORMAT', 'WELCOME', 'TO']),
#  WordList(['WELCOME', 'TO', 'OUR']),
#  WordList(['TO', 'OUR', 'HOME']),
#  WordList(['OUR', 'HOME', 'WOODEN']),
#  WordList(['HOME', 'WOODEN', 'UNION']),
#  WordList(['WOODEN', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'BUNTING']),
#  WordList(['JACK', 'BUNTING', 'WOODEN']),
#  WordList(['BUNTING', 'WOODEN', 'ROUNDERS']),
#  WordList(['WOODEN', 'ROUNDERS', 'GARDEN']),
#  WordList(['ROUNDERS', 'GARDEN', 'SET']),
#  WordList(['GARDEN', 'SET', 'PARTY']),
#  WordList(['SET', 'PARTY', 'BUNTING']),
#  WordList(['PARTY', 'BUNTING', 'KEY']),
#  WordList(['BUNTING', 'KEY', 'FOB']),
#  WordList(['KEY', 'FOB', 'FRONT']),
#  WordList(['FOB', 'FRONT', 'DOOR']),
#  WordList(['FRONT', 'DOOR', 'KEY']),
#  WordList(['DOOR', 'KEY', 'FOB']),
#  WordList(['KEY', 'FOB', 'BACK']),
#  WordList(['FOB', 'BACK', 'DOOR']),
#  WordList(['BACK', 'DOOR', 'KEY']),
#  WordList(['DOOR', 'KEY', 'FOB']),
#  WordList(['KEY', 'FOB', 'GARAGE']),
#  WordList(['FOB', 'GARAGE', 'DESIGN']),
#  WordList(['GARAGE', 'DESIGN', 'KEY']),
#  WordList(['DESIGN', 'KEY', 'FOB']),
#  WordList(['KEY', 'FOB', 'SHED']),
#  WordList(['FOB', 'SHED', '6']),
#  WordList(['SHED', '6', 'RIBBONS']),
#  WordList(['6', 'RIBBONS', 'RUSTIC']),
#  WordList(['RIBBONS', 'RUSTIC', 'CHARM']),
#  WordList(['RUSTIC', 'CHARM', 'IVORY']),
#  WordList(['CHARM', 'IVORY', 'SWEETHEART']),
#  WordList(['IVORY', 'SWEETHEART', 'WIRE']),
#  WordList(['SWEETHEART', 'WIRE', 'LETTER']),
#  WordList(['WIRE', 'LETTER', 'RACK']),
#  WordList(['LETTER', 'RACK', 'TOILET']),
#  WordList(['RACK', 'TOILET', 'SIGN']),
#  WordList(['TOILET', 'SIGN', 'OCCUPIED']),
#  WordList(['SIGN', 'OCCUPIED', 'OR']),
#  WordList(['OCCUPIED', 'OR', 'VACANT']),
#  WordList(['OR', 'VACANT', 'REGENCY']),
#  WordList(['VACANT', 'REGENCY', 'CAKE']),
#  WordList(['REGENCY', 'CAKE', 'FORK']),
#  WordList(['CAKE', 'FORK', 'REGENCY']),
#  WordList(['FORK', 'REGENCY', 'TEA']),
#  WordList(['REGENCY', 'TEA', 'SPOON']),
#  WordList(['TEA', 'SPOON', 'REGENCY']),
#  WordList(['SPOON', 'REGENCY', 'SUGAR']),
#  WordList(['REGENCY', 'SUGAR', 'TONGS']),
#  WordList(['SUGAR', 'TONGS', 'REGENCY']),
#  WordList(['TONGS', 'REGENCY', 'TEA']),
#  WordList(['REGENCY', 'TEA', 'STRAINER']),
#  WordList(['TEA', 'STRAINER', 'REGENCY']),
#  WordList(['STRAINER', 'REGENCY', 'CAKE']),
#  WordList(['REGENCY', 'CAKE', 'SLICE']),
#  WordList(['CAKE', 'SLICE', 'TREASURE']),
#  WordList(['SLICE', 'TREASURE', 'ISLAND']),
#  WordList(['TREASURE', 'ISLAND', 'BOOK']),
#  WordList(['ISLAND', 'BOOK', 'BOX']),
#  WordList(['BOOK', 'BOX', 'ABC']),
#  WordList(['BOX', 'ABC', 'TREASURE']),
#  WordList(['ABC', 'TREASURE', 'BOOK']),
#  WordList(['TREASURE', 'BOOK', 'BOX']),
#  WordList(['BOOK', 'BOX', 'TRAVEL']),
#  WordList(['BOX', 'TRAVEL', 'CARD']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'FLOWER']),
#  WordList(['WALLET', 'FLOWER', 'MEADOW']),
#  WordList(['FLOWER', 'MEADOW', 'TRAVEL']),
#  WordList(['MEADOW', 'TRAVEL', 'CARD']),
#  WordList(['TRAVEL', 'CARD', 'WALLET']),
#  WordList(['CARD', 'WALLET', 'VINTAGE']),
#  WordList(['WALLET', 'VINTAGE', 'TICKET']),
#  WordList(['VINTAGE', 'TICKET', 'EDWARDIAN']),
#  WordList(['TICKET', 'EDWARDIAN', 'HEART']),
#  WordList(['EDWARDIAN', 'HEART', 'PHOTO']),
#  WordList(['HEART', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'FELTCRAFT']),
#  WordList(['FRAME', 'FELTCRAFT', 'GIRL']),
#  WordList(['FELTCRAFT', 'GIRL', 'AMELIE']),
#  WordList(['GIRL', 'AMELIE', 'KIT']),
#  WordList(['AMELIE', 'KIT', 'FOOD']),
#  WordList(['KIT', 'FOOD', 'COVER']),
#  WordList(['FOOD', 'COVER', 'WITH']),
#  WordList(['COVER', 'WITH', 'BEADS']),
#  WordList(['WITH', 'BEADS', 'SET']),
#  WordList(['BEADS', 'SET', '2']),
#  WordList(['SET', '2', 'REGENCY']),
#  WordList(['2', 'REGENCY', 'CAKESTAND']),
#  WordList(['REGENCY', 'CAKESTAND', '3']),
#  WordList(['CAKESTAND', '3', 'TIER']),
#  WordList(['3', 'TIER', 'VINTAGE']),
#  WordList(['TIER', 'VINTAGE', 'UNION']),
#  WordList(['VINTAGE', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'BUNTING']),
#  WordList(['JACK', 'BUNTING', 'LARGE']),
#  WordList(['BUNTING', 'LARGE', 'ANTIQUE']),
#  WordList(['LARGE', 'ANTIQUE', 'WHITE']),
#  WordList(['ANTIQUE', 'WHITE', 'PHOTO']),
#  WordList(['WHITE', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'PARISIENNE']),
#  WordList(['FRAME', 'PARISIENNE', 'CURIO']),
#  WordList(['PARISIENNE', 'CURIO', 'CABINET']),
#  WordList(['CURIO', 'CABINET', 'PARISIENNE']),
#  WordList(['CABINET', 'PARISIENNE', 'KEY']),
#  WordList(['PARISIENNE', 'KEY', 'CABINET']),
#  WordList(['KEY', 'CABINET', 'PARISIENNE']),
#  WordList(['CABINET', 'PARISIENNE', 'SEWING']),
#  WordList(['PARISIENNE', 'SEWING', 'BOX']),
#  WordList(['SEWING', 'BOX', 'PARISIENNE']),
#  WordList(['BOX', 'PARISIENNE', 'JEWELLERY']),
#  WordList(['PARISIENNE', 'JEWELLERY', 'DRAWER']),
#  WordList(['JEWELLERY', 'DRAWER', 'SMALL']),
#  WordList(['DRAWER', 'SMALL', 'PARISIENNE']),
#  WordList(['SMALL', 'PARISIENNE', 'HEART']),
#  WordList(['PARISIENNE', 'HEART', 'PHOTO']),
#  WordList(['HEART', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'GLASS']),
#  WordList(['FRAME', 'GLASS', 'BON']),
#  WordList(['GLASS', 'BON', 'BON']),
#  WordList(['BON', 'BON', 'JAR']),
#  WordList(['BON', 'JAR', 'CLASSIC']),
#  WordList(['JAR', 'CLASSIC', 'SUGAR']),
#  WordList(['CLASSIC', 'SUGAR', 'DISPENSER']),
#  WordList(['SUGAR', 'DISPENSER', 'DOILEY']),
#  WordList(['DISPENSER', 'DOILEY', 'STORAGE']),
#  WordList(['DOILEY', 'STORAGE', 'TIN']),
#  WordList(['STORAGE', 'TIN', 'SET']),
#  WordList(['TIN', 'SET', 'OF']),
#  WordList(['SET', 'OF', '4']),
#  WordList(['OF', '4', 'KNICK']),
#  WordList(['4', 'KNICK', 'KNACK']),
#  WordList(['KNICK', 'KNACK', 'TINS']),
#  WordList(['KNACK', 'TINS', 'DOILEY']),
#  WordList(['TINS', 'DOILEY', 'REGENCY']),
#  WordList(['DOILEY', 'REGENCY', 'MILK']),
#  WordList(['REGENCY', 'MILK', 'JUG']),
#  WordList(['MILK', 'JUG', 'PINK']),
#  WordList(['JUG', 'PINK', 'REGENCY']),
#  WordList(['PINK', 'REGENCY', 'TEAPOT']),
#  WordList(['REGENCY', 'TEAPOT', 'ROSES']),
#  WordList(['TEAPOT', 'ROSES', 'SET']),
#  WordList(['ROSES', 'SET', 'OF']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'REGENCY']),
#  WordList(['3', 'REGENCY', 'CAKE']),
#  WordList(['REGENCY', 'CAKE', 'TINS']),
#  WordList(['CAKE', 'TINS', 'DRAWER']),
#  WordList(['TINS', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'IVORY']),
#  WordList(['GLAZE', 'IVORY', 'DRAWER']),
#  WordList(['IVORY', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'PINK']),
#  WordList(['GLAZE', 'PINK', 'DRAWER']),
#  WordList(['PINK', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'GREEN']),
#  WordList(['GLAZE', 'GREEN', 'DRAWER']),
#  WordList(['GREEN', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'CRACKLE']),
#  WordList(['KNOB', 'CRACKLE', 'GLAZE']),
#  WordList(['CRACKLE', 'GLAZE', 'BLUE']),
#  WordList(['GLAZE', 'BLUE', 'FRENCH']),
#  WordList(['BLUE', 'FRENCH', 'ENAMEL']),
#  WordList(['FRENCH', 'ENAMEL', 'CANDLEHOLDER']),
#  WordList(['ENAMEL', 'CANDLEHOLDER', 'PAPER']),
#  WordList(['CANDLEHOLDER', 'PAPER', 'BUNTING']),
#  WordList(['PAPER', 'BUNTING', 'RETROSPOT']),
#  WordList(['BUNTING', 'RETROSPOT', 'PAPER']),
#  WordList(['RETROSPOT', 'PAPER', 'BUNTING']),
#  WordList(['PAPER', 'BUNTING', 'VINTAGE']),
#  WordList(['BUNTING', 'VINTAGE', 'PAISLEY']),
#  WordList(['VINTAGE', 'PAISLEY', 'PAPER']),
#  WordList(['PAISLEY', 'PAPER', 'BUNTING']),
#  WordList(['PAPER', 'BUNTING', 'COLOURED']),
#  WordList(['BUNTING', 'COLOURED', 'LACE']),
#  WordList(['COLOURED', 'LACE', 'WRAP']),
#  WordList(['LACE', 'WRAP', 'PAISLEY']),
#  WordList(['WRAP', 'PAISLEY', 'PARK']),
#  WordList(['PAISLEY', 'PARK', 'WRAP']),
#  WordList(['PARK', 'WRAP', 'RED']),
#  WordList(['WRAP', 'RED', 'DOILEY']),
#  WordList(['RED', 'DOILEY', 'WRAP']),
#  WordList(['DOILEY', 'WRAP', 'GINGHAM']),
#  WordList(['WRAP', 'GINGHAM', 'ROSE']),
#  WordList(['GINGHAM', 'ROSE', 'RIBBON']),
#  WordList(['ROSE', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'CHRISTMAS']),
#  WordList(['REEL', 'CHRISTMAS', 'SOCK']),
#  WordList(['CHRISTMAS', 'SOCK', 'BAUBLE']),
#  WordList(['SOCK', 'BAUBLE', '3']),
#  WordList(['BAUBLE', '3', 'RAFFIA']),
#  WordList(['3', 'RAFFIA', 'RIBBONS']),
#  WordList(['RAFFIA', 'RIBBONS', 'VINTAGE']),
#  WordList(['RIBBONS', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['VINTAGE', 'CHRISTMAS', 'TRADITIONAL']),
#  WordList(['CHRISTMAS', 'TRADITIONAL', 'KNITTING']),
#  WordList(['TRADITIONAL', 'KNITTING', 'NANCY']),
#  WordList(['KNITTING', 'NANCY', 'DOORMAT']),
#  WordList(['NANCY', 'DOORMAT', 'WELCOME']),
#  WordList(['DOORMAT', 'WELCOME', 'PUPPIES']),
#  WordList(['WELCOME', 'PUPPIES', 'CHILDREN']),
#  WordList(['PUPPIES', 'CHILDREN', "'S"]),
#  WordList(['CHILDREN', "'S", 'APRON']),
#  WordList(["'S", 'APRON', 'DOLLY']),
#  WordList(['APRON', 'DOLLY', 'GIRL']),
#  WordList(['DOLLY', 'GIRL', 'CHILDRENS']),
#  WordList(['GIRL', 'CHILDRENS', 'APRON']),
#  WordList(['CHILDRENS', 'APRON', 'SPACEBOY']),
#  WordList(['APRON', 'SPACEBOY', 'DESIGN']),
#  WordList(['SPACEBOY', 'DESIGN', 'EMBROIDERED']),
#  WordList(['DESIGN', 'EMBROIDERED', 'RIBBON']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'SALLY']),
#  WordList(['REEL', 'SALLY', 'EMBROIDERED']),
#  WordList(['SALLY', 'EMBROIDERED', 'RIBBON']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'SUSIE']),
#  WordList(['REEL', 'SUSIE', 'EMBROIDERED']),
#  WordList(['SUSIE', 'EMBROIDERED', 'RIBBON']),
#  WordList(['EMBROIDERED', 'RIBBON', 'REEL']),
#  WordList(['RIBBON', 'REEL', 'EMILY']),
#  WordList(['REEL', 'EMILY', 'PANTRY']),
#  WordList(['EMILY', 'PANTRY', 'MAGNETIC']),
#  WordList(['PANTRY', 'MAGNETIC', 'SHOPPING']),
#  WordList(['MAGNETIC', 'SHOPPING', 'LIST']),
#  WordList(['SHOPPING', 'LIST', 'SET']),
#  WordList(['LIST', 'SET', 'OF']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'SNACK']),
#  WordList(['6', 'SNACK', 'LOAF']),
#  WordList(['SNACK', 'LOAF', 'BAKING']),
#  WordList(['LOAF', 'BAKING', 'CASES']),
#  WordList(['BAKING', 'CASES', 'SET']),
#  WordList(['CASES', 'SET', 'OF']),
#  WordList(['SET', 'OF', '12']),
#  WordList(['OF', '12', 'MINI']),
#  WordList(['12', 'MINI', 'LOAF']),
#  WordList(['MINI', 'LOAF', 'BAKING']),
#  WordList(['LOAF', 'BAKING', 'CASES']),
#  WordList(['BAKING', 'CASES', 'DRAWER']),
#  WordList(['CASES', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'VINTAGE']),
#  WordList(['KNOB', 'VINTAGE', 'GLASS']),
#  WordList(['VINTAGE', 'GLASS', 'BALL']),
#  WordList(['GLASS', 'BALL', 'CARD']),
#  WordList(['BALL', 'CARD', 'HOLDER']),
#  WordList(['CARD', 'HOLDER', 'LOVE']),
#  WordList(['HOLDER', 'LOVE', 'BIRD']),
#  WordList(['LOVE', 'BIRD', 'LARGE']),
#  WordList(['BIRD', 'LARGE', 'FOOT']),
#  WordList(['LARGE', 'FOOT', 'STOOL']),
#  WordList(['FOOT', 'STOOL', 'HOME']),
#  WordList(['STOOL', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['SWEET', 'HOME', 'PETIT']),
#  WordList(['HOME', 'PETIT', 'TRAY']),
#  WordList(['PETIT', 'TRAY', 'CHIC']),
#  WordList(['TRAY', 'CHIC', 'SWEET']),
#  WordList(['CHIC', 'SWEET', 'HEART']),
#  WordList(['SWEET', 'HEART', 'CAKE']),
#  WordList(['HEART', 'CAKE', 'CARRIER']),
#  WordList(['CAKE', 'CARRIER', 'PACK']),
#  WordList(['CARRIER', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', 'SIX']),
#  WordList(['OF', 'SIX', 'LED']),
#  WordList(['SIX', 'LED', 'TEA']),
#  WordList(['LED', 'TEA', 'LIGHTS']),
#  WordList(['TEA', 'LIGHTS', '3']),
#  WordList(['LIGHTS', '3', 'RAFFIA']),
#  WordList(['3', 'RAFFIA', 'RIBBONS']),
#  WordList(['RAFFIA', 'RIBBONS', '50']),
#  WordList(['RIBBONS', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'PAPER']),
#  WordList(['CHRISTMAS', 'PAPER', 'CHAIN']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', '50']),
#  WordList(['KIT', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['CHRISTMAS', 'SCANDINAVIAN', 'REDS']),
#  WordList(['SCANDINAVIAN', 'REDS', 'RIBBONS']),
#  WordList(['REDS', 'RIBBONS', 'Manual']),
#  WordList(['RIBBONS', 'Manual', 'BISCUIT']),
#  WordList(['Manual', 'BISCUIT', 'TIN']),
#  WordList(['BISCUIT', 'TIN', 'VINTAGE']),
#  WordList(['TIN', 'VINTAGE', 'GREEN']),
#  WordList(['VINTAGE', 'GREEN', 'ROUND']),
#  WordList(['GREEN', 'ROUND', 'CAKE']),
#  WordList(['ROUND', 'CAKE', 'TIN']),
#  WordList(['CAKE', 'TIN', 'VINTAGE']),
#  WordList(['TIN', 'VINTAGE', 'GREEN']),
#  WordList(['VINTAGE', 'GREEN', '3']),
#  WordList(['GREEN', '3', 'TIER']),
#  WordList(['3', 'TIER', 'CAKE']),
#  WordList(['TIER', 'CAKE', 'TIN']),
#  WordList(['CAKE', 'TIN', 'GREEN']),
#  WordList(['TIN', 'GREEN', 'AND']),
#  WordList(['GREEN', 'AND', 'CREAM']),
#  WordList(['AND', 'CREAM', 'PACK']),
#  WordList(['CREAM', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '20']),
#  WordList(['OF', '20', 'NAPKINS']),
#  WordList(['20', 'NAPKINS', 'PANTRY']),
#  WordList(['NAPKINS', 'PANTRY', 'DESIGN']),
#  WordList(['PANTRY', 'DESIGN', 'PACK']),
#  WordList(['DESIGN', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '6']),
#  WordList(['OF', '6', 'BIRDY']),
#  WordList(['6', 'BIRDY', 'GIFT']),
#  WordList(['BIRDY', 'GIFT', 'TAGS']),
#  WordList(['GIFT', 'TAGS', 'PAPER']),
#  WordList(['TAGS', 'PAPER', 'CHAIN']),
#  WordList(['PAPER', 'CHAIN', 'KIT']),
#  WordList(['CHAIN', 'KIT', 'EMPIRE']),
#  WordList(['KIT', 'EMPIRE', 'STRAWBERRY']),
#  WordList(['EMPIRE', 'STRAWBERRY', 'CERAMIC']),
#  WordList(['STRAWBERRY', 'CERAMIC', 'TRINKET']),
#  WordList(['CERAMIC', 'TRINKET', 'BOX']),
#  WordList(['TRINKET', 'BOX', 'NATURAL']),
#  WordList(['BOX', 'NATURAL', 'SLATE']),
#  WordList(['NATURAL', 'SLATE', 'HEART']),
#  WordList(['SLATE', 'HEART', 'CHALKBOARD']),
#  WordList(['HEART', 'CHALKBOARD', 'PACK']),
#  WordList(['CHALKBOARD', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '12']),
#  WordList(['OF', '12', '50']),
#  WordList(['12', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'TISSUES']),
#  WordList(['CHRISTMAS', 'TISSUES', 'HEART']),
#  WordList(['TISSUES', 'HEART', 'SHAPED']),
#  WordList(['HEART', 'SHAPED', 'HOLLY']),
#  WordList(['SHAPED', 'HOLLY', 'WREATH']),
#  WordList(['HOLLY', 'WREATH', '36']),
#  WordList(['WREATH', '36', 'DOILIES']),
#  WordList(['36', 'DOILIES', 'VINTAGE']),
#  WordList(['DOILIES', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['VINTAGE', 'CHRISTMAS', 'ROLL']),
#  WordList(['CHRISTMAS', 'ROLL', 'WRAP']),
#  WordList(['ROLL', 'WRAP', '50']),
#  WordList(['WRAP', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'ROLL']),
#  WordList(['CHRISTMAS', 'ROLL', 'WRAP']),
#  WordList(['ROLL', 'WRAP', 'VINTAGE']),
#  WordList(['WRAP', 'VINTAGE', 'SPOT']),
#  WordList(['VINTAGE', 'SPOT', 'BOX']),
#  WordList(['SPOT', 'BOX', 'OF']),
#  WordList(['BOX', 'OF', '6']),
#  WordList(['OF', '6', 'MINI']),
#  WordList(['6', 'MINI', '50']),
#  WordList(['MINI', '50', "'S"]),
#  WordList(['50', "'S", 'CRACKERS']),
#  WordList(["'S", 'CRACKERS', '6']),
#  WordList(['CRACKERS', '6', 'GIFT']),
#  WordList(['6', 'GIFT', 'TAGS']),
#  WordList(['GIFT', 'TAGS', '50']),
#  WordList(['TAGS', '50', "'S"]),
#  WordList(['50', "'S", 'CHRISTMAS']),
#  WordList(["'S", 'CHRISTMAS', 'ANTIQUE']),
#  WordList(['CHRISTMAS', 'ANTIQUE', 'SILVER']),
#  WordList(['ANTIQUE', 'SILVER', 'T-LIGHT']),
#  WordList(['SILVER', 'T-LIGHT', 'GLASS']),
#  WordList(['T-LIGHT', 'GLASS', 'SET']),
#  WordList(['GLASS', 'SET', 'OF']),
#  WordList(['SET', 'OF', '6']),
#  WordList(['OF', '6', 'RIBBONS']),
#  WordList(['6', 'RIBBONS', 'VINTAGE']),
#  WordList(['RIBBONS', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['VINTAGE', 'CHRISTMAS', '60']),
#  WordList(['CHRISTMAS', '60', 'CAKE']),
#  WordList(['60', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', 'VINTAGE']),
#  WordList(['CASES', 'VINTAGE', 'CHRISTMAS']),
#  WordList(['VINTAGE', 'CHRISTMAS', 'GLASS']),
#  WordList(['CHRISTMAS', 'GLASS', 'APOTHECARY']),
#  WordList(['GLASS', 'APOTHECARY', 'BOTTLE']),
#  WordList(['APOTHECARY', 'BOTTLE', 'TONIC']),
#  WordList(['BOTTLE', 'TONIC', 'GLASS']),
#  WordList(['TONIC', 'GLASS', 'APOTHECARY']),
#  WordList(['GLASS', 'APOTHECARY', 'BOTTLE']),
#  WordList(['APOTHECARY', 'BOTTLE', 'PERFUME']),
#  WordList(['BOTTLE', 'PERFUME', 'VICTORIAN']),
#  WordList(['PERFUME', 'VICTORIAN', 'SEWING']),
#  WordList(['VICTORIAN', 'SEWING', 'BOX']),
#  WordList(['SEWING', 'BOX', 'LARGE']),
#  WordList(['BOX', 'LARGE', 'HOT']),
#  WordList(['LARGE', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'TEA']),
#  WordList(['BOTTLE', 'TEA', 'AND']),
#  WordList(['TEA', 'AND', 'SYMPATHY']),
#  WordList(['AND', 'SYMPATHY', 'RED']),
#  WordList(['SYMPATHY', 'RED', 'HANGING']),
#  WordList(['RED', 'HANGING', 'HEART']),
#  WordList(['HANGING', 'HEART', 'T-LIGHT']),
#  WordList(['HEART', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'WOOD']),
#  WordList(['HOLDER', 'WOOD', 'BLACK']),
#  WordList(['WOOD', 'BLACK', 'BOARD']),
#  WordList(['BLACK', 'BOARD', 'ANT']),
#  WordList(['BOARD', 'ANT', 'WHITE']),
#  WordList(['ANT', 'WHITE', 'FINISH']),
#  WordList(['WHITE', 'FINISH', 'ENAMEL']),
#  WordList(['FINISH', 'ENAMEL', 'BREAD']),
#  WordList(['ENAMEL', 'BREAD', 'BIN']),
#  WordList(['BREAD', 'BIN', 'CREAM']),
#  WordList(['BIN', 'CREAM', 'MEMO']),
#  WordList(['CREAM', 'MEMO', 'BOARD']),
#  WordList(['MEMO', 'BOARD', 'COTTAGE']),
#  WordList(['BOARD', 'COTTAGE', 'DESIGN']),
#  WordList(['COTTAGE', 'DESIGN', 'FAMILY']),
#  WordList(['DESIGN', 'FAMILY', 'PHOTO']),
#  WordList(['FAMILY', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', 'CORNICE']),
#  WordList(['FRAME', 'CORNICE', 'PICTURE']),
#  WordList(['CORNICE', 'PICTURE', 'FRAME']),
#  WordList(['PICTURE', 'FRAME', 'WOOD']),
#  WordList(['FRAME', 'WOOD', 'TRIPLE']),
#  WordList(['WOOD', 'TRIPLE', 'PORTRAIT']),
#  WordList(['TRIPLE', 'PORTRAIT', 'PAINTED']),
#  WordList(['PORTRAIT', 'PAINTED', 'METAL']),
#  WordList(['PAINTED', 'METAL', 'PEARS']),
#  WordList(['METAL', 'PEARS', 'ASSORTED']),
#  WordList(['PEARS', 'ASSORTED', 'CREAM']),
#  WordList(['ASSORTED', 'CREAM', 'SWEETHEART']),
#  WordList(['CREAM', 'SWEETHEART', 'MINI']),
#  WordList(['SWEETHEART', 'MINI', 'CHEST']),
#  WordList(['MINI', 'CHEST', 'PHOTO']),
#  WordList(['CHEST', 'PHOTO', 'FRAME']),
#  WordList(['PHOTO', 'FRAME', '3']),
#  WordList(['FRAME', '3', 'CLASSIC']),
#  WordList(['3', 'CLASSIC', 'HANGING']),
#  WordList(['CLASSIC', 'HANGING', 'HEART']),
#  WordList(['HANGING', 'HEART', 'FILIGREE']),
#  WordList(['HEART', 'FILIGREE', 'DOVE']),
#  WordList(['FILIGREE', 'DOVE', 'SMALL']),
#  WordList(['DOVE', 'SMALL', 'WHITE']),
#  WordList(['SMALL', 'WHITE', 'WOOD']),
#  WordList(['WHITE', 'WOOD', 'GARDEN']),
#  WordList(['WOOD', 'GARDEN', 'PLANT']),
#  WordList(['GARDEN', 'PLANT', 'LADDER']),
#  WordList(['PLANT', 'LADDER', 'DOORMAT']),
#  WordList(['LADDER', 'DOORMAT', 'HEARTS']),
#  WordList(['DOORMAT', 'HEARTS', 'DOORMAT']),
#  WordList(['HEARTS', 'DOORMAT', 'RED']),
#  WordList(['DOORMAT', 'RED', 'RETROSPOT']),
#  WordList(['RED', 'RETROSPOT', 'COLOUR']),
#  WordList(['RETROSPOT', 'COLOUR', 'GLASS']),
#  WordList(['COLOUR', 'GLASS', 'T-LIGHT']),
#  WordList(['GLASS', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'HANGING']),
#  WordList(['HOLDER', 'HANGING', 'VINTAGE']),
#  WordList(['HANGING', 'VINTAGE', 'UNION']),
#  WordList(['VINTAGE', 'UNION', 'JACK']),
#  WordList(['UNION', 'JACK', 'MEMOBOARD']),
#  WordList(['JACK', 'MEMOBOARD', 'ROSE']),
#  WordList(['MEMOBOARD', 'ROSE', 'COTTAGE']),
#  WordList(['ROSE', 'COTTAGE', 'KEEPSAKE']),
#  WordList(['COTTAGE', 'KEEPSAKE', 'BOX']),
#  WordList(['KEEPSAKE', 'BOX', 'SET']),
#  WordList(['BOX', 'SET', 'OF']),
#  WordList(['SET', 'OF', '3']),
#  WordList(['OF', '3', 'NOTEBOOKS']),
#  WordList(['3', 'NOTEBOOKS', 'IN']),
#  WordList(['NOTEBOOKS', 'IN', 'PARCEL']),
#  WordList(['IN', 'PARCEL', 'CUPBOARD']),
#  WordList(['PARCEL', 'CUPBOARD', '3']),
#  WordList(['CUPBOARD', '3', 'DRAWER']),
#  WordList(['3', 'DRAWER', 'MA']),
#  WordList(['DRAWER', 'MA', 'CAMPAGNE']),
#  WordList(['MA', 'CAMPAGNE', 'GARLAND']),
#  WordList(['CAMPAGNE', 'GARLAND', 'WOODEN']),
#  WordList(['GARLAND', 'WOODEN', 'HAPPY']),
#  WordList(['WOODEN', 'HAPPY', 'EASTER']),
#  WordList(['HAPPY', 'EASTER', 'HANGING']),
#  WordList(['EASTER', 'HANGING', 'METAL']),
#  WordList(['HANGING', 'METAL', 'RABBIT']),
#  WordList(['METAL', 'RABBIT', 'DECORATION']),
#  WordList(['RABBIT', 'DECORATION', 'HOT']),
#  WordList(['DECORATION', 'HOT', 'BATHS']),
#  WordList(['HOT', 'BATHS', 'SOAP']),
#  WordList(['BATHS', 'SOAP', 'HOLDER']),
#  WordList(['SOAP', 'HOLDER', 'DOORMAT']),
#  WordList(['HOLDER', 'DOORMAT', 'FAIRY']),
#  WordList(['DOORMAT', 'FAIRY', 'CAKE']),
#  WordList(['FAIRY', 'CAKE', 'DOORMAT']),
#  WordList(['CAKE', 'DOORMAT', 'SPOTTY']),
#  WordList(['DOORMAT', 'SPOTTY', 'HOME']),
#  WordList(['SPOTTY', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['SWEET', 'HOME', 'LOVEBIRD']),
#  WordList(['HOME', 'LOVEBIRD', 'HANGING']),
#  WordList(['LOVEBIRD', 'HANGING', 'DECORATION']),
#  WordList(['HANGING', 'DECORATION', 'WHITE']),
#  WordList(['DECORATION', 'WHITE', 'METAL']),
#  WordList(['WHITE', 'METAL', '4']),
#  WordList(['METAL', '4', 'HOOK']),
#  WordList(['4', 'HOOK', 'HANGER']),
#  WordList(['HOOK', 'HANGER', 'FRENCH']),
#  WordList(['HANGER', 'FRENCH', 'CHATEAU']),
#  WordList(['FRENCH', 'CHATEAU', 'CREAM']),
#  WordList(['CHATEAU', 'CREAM', 'HEART']),
#  WordList(['CREAM', 'HEART', 'CARD']),
#  WordList(['HEART', 'CARD', 'HOLDER']),
#  WordList(['CARD', 'HOLDER', 'DOORMAT']),
#  WordList(['HOLDER', 'DOORMAT', 'UNION']),
#  WordList(['DOORMAT', 'UNION', 'FLAG']),
#  WordList(['UNION', 'FLAG', 'DOORMAT']),
#  WordList(['FLAG', 'DOORMAT', '3']),
#  WordList(['DOORMAT', '3', 'SMILEY']),
#  WordList(['3', 'SMILEY', 'CATS']),
#  WordList(['SMILEY', 'CATS', 'VICTORIAN']),
#  WordList(['CATS', 'VICTORIAN', 'SEWING']),
#  WordList(['VICTORIAN', 'SEWING', 'BOX']),
#  WordList(['SEWING', 'BOX', 'SMALL']),
#  WordList(['BOX', 'SMALL', 'SINGLE']),
#  WordList(['SMALL', 'SINGLE', 'HEART']),
#  WordList(['SINGLE', 'HEART', 'ZINC']),
#  WordList(['HEART', 'ZINC', 'T-LIGHT']),
#  WordList(['ZINC', 'T-LIGHT', 'HOLDER']),
#  WordList(['T-LIGHT', 'HOLDER', 'FINE']),
#  WordList(['HOLDER', 'FINE', 'WICKER']),
#  WordList(['FINE', 'WICKER', 'HEART']),
#  WordList(['WICKER', 'HEART', 'FOUR']),
#  WordList(['HEART', 'FOUR', 'HOOK']),
#  WordList(['FOUR', 'HOOK', 'WHITE']),
#  WordList(['HOOK', 'WHITE', 'LOVEBIRDS']),
#  WordList(['WHITE', 'LOVEBIRDS', 'POLYESTER']),
#  WordList(['LOVEBIRDS', 'POLYESTER', 'FILLER']),
#  WordList(['POLYESTER', 'FILLER', 'PAD']),
#  WordList(['FILLER', 'PAD', '40x40cm']),
#  WordList(['PAD', '40x40cm', 'CREAM']),
#  WordList(['40x40cm', 'CREAM', 'WALL']),
#  WordList(['CREAM', 'WALL', 'PLANTER']),
#  WordList(['WALL', 'PLANTER', 'HEART']),
#  WordList(['PLANTER', 'HEART', 'SHAPED']),
#  WordList(['HEART', 'SHAPED', 'DOORMAT']),
#  WordList(['SHAPED', 'DOORMAT', 'FANCY']),
#  WordList(['DOORMAT', 'FANCY', 'FONT']),
#  WordList(['FANCY', 'FONT', 'HOME']),
#  WordList(['FONT', 'HOME', 'SWEET']),
#  WordList(['HOME', 'SWEET', 'HOME']),
#  WordList(['SWEET', 'HOME', 'LANTERN']),
#  WordList(['HOME', 'LANTERN', 'CREAM']),
#  WordList(['LANTERN', 'CREAM', 'GAZEBO']),
#  WordList(['CREAM', 'GAZEBO', 'WHITE']),
#  WordList(['GAZEBO', 'WHITE', 'SPOT']),
#  WordList(['WHITE', 'SPOT', 'BLUE']),
#  WordList(['SPOT', 'BLUE', 'CERAMIC']),
#  WordList(['BLUE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'WHITE']),
#  WordList(['KNOB', 'WHITE', 'SPOT']),
#  WordList(['WHITE', 'SPOT', 'RED']),
#  WordList(['SPOT', 'RED', 'CERAMIC']),
#  WordList(['RED', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'BLUE']),
#  WordList(['KNOB', 'BLUE', 'STRIPE']),
#  WordList(['BLUE', 'STRIPE', 'CERAMIC']),
#  WordList(['STRIPE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'RED']),
#  WordList(['KNOB', 'RED', 'STRIPE']),
#  WordList(['RED', 'STRIPE', 'CERAMIC']),
#  WordList(['STRIPE', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'VINTAGE']),
#  WordList(['KNOB', 'VINTAGE', 'CREAM']),
#  WordList(['VINTAGE', 'CREAM', 'DOG']),
#  WordList(['CREAM', 'DOG', 'FOOD']),
#  WordList(['DOG', 'FOOD', 'CONTAINER']),
#  WordList(['FOOD', 'CONTAINER', 'DOG']),
#  WordList(['CONTAINER', 'DOG', 'BOWL']),
#  WordList(['DOG', 'BOWL', 'VINTAGE']),
#  WordList(['BOWL', 'VINTAGE', 'CREAM']),
#  WordList(['VINTAGE', 'CREAM', 'VINTAGE']),
#  WordList(['CREAM', 'VINTAGE', 'CREAM']),
#  WordList(['VINTAGE', 'CREAM', 'CAT']),
#  WordList(['CREAM', 'CAT', 'FOOD']),
#  WordList(['CAT', 'FOOD', 'CONTAINER']),
#  WordList(['FOOD', 'CONTAINER', 'CAT']),
#  WordList(['CONTAINER', 'CAT', 'BOWL']),
#  WordList(['CAT', 'BOWL', 'VINTAGE']),
#  WordList(['BOWL', 'VINTAGE', 'CREAM']),
#  WordList(['VINTAGE', 'CREAM', 'BLUE']),
#  WordList(['CREAM', 'BLUE', 'SPOT']),
#  WordList(['BLUE', 'SPOT', 'CERAMIC']),
#  WordList(['SPOT', 'CERAMIC', 'DRAWER']),
#  WordList(['CERAMIC', 'DRAWER', 'KNOB']),
#  WordList(['DRAWER', 'KNOB', 'WOODEN']),
#  WordList(['KNOB', 'WOODEN', 'STAR']),
#  WordList(['WOODEN', 'STAR', 'CHRISTMAS']),
#  WordList(['STAR', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['CHRISTMAS', 'SCANDINAVIAN', 'WOODEN']),
#  WordList(['SCANDINAVIAN', 'WOODEN', 'TREE']),
#  WordList(['WOODEN', 'TREE', 'CHRISTMAS']),
#  WordList(['TREE', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['CHRISTMAS', 'SCANDINAVIAN', 'WOODEN']),
#  WordList(['SCANDINAVIAN', 'WOODEN', 'HEART']),
#  WordList(['WOODEN', 'HEART', 'CHRISTMAS']),
#  WordList(['HEART', 'CHRISTMAS', 'SCANDINAVIAN']),
#  WordList(['CHRISTMAS', 'SCANDINAVIAN', 'CHOCOLATE']),
#  WordList(['SCANDINAVIAN', 'CHOCOLATE', 'HOT']),
#  WordList(['CHOCOLATE', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'HOT']),
#  WordList(['BOTTLE', 'HOT', 'WATER']),
#  WordList(['HOT', 'WATER', 'BOTTLE']),
#  WordList(['WATER', 'BOTTLE', 'KEEP']),
#  WordList(['BOTTLE', 'KEEP', 'CALM']),
#  WordList(['KEEP', 'CALM', 'JUMBO']),
#  WordList(['CALM', 'JUMBO', 'BAG']),
#  WordList(['JUMBO', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'POLKADOT']),
#  WordList(['PINK', 'POLKADOT', 'JUMBO']),
#  WordList(['POLKADOT', 'JUMBO', 'BAG']),
#  WordList(['JUMBO', 'BAG', 'BAROQUE']),
#  WordList(['BAG', 'BAROQUE', 'BLACK']),
#  WordList(['BAROQUE', 'BLACK', 'WHITE']),
#  WordList(['BLACK', 'WHITE', 'JUMBO']),
#  WordList(['WHITE', 'JUMBO', 'BAG']),
#  WordList(['JUMBO', 'BAG', 'CHARLIE']),
#  WordList(['BAG', 'CHARLIE', 'AND']),
#  WordList(['CHARLIE', 'AND', 'LOLA']),
#  WordList(['AND', 'LOLA', 'TOYS']),
#  WordList(['LOLA', 'TOYS', 'STRAWBERRY']),
#  WordList(['TOYS', 'STRAWBERRY', 'CHARLOTTE']),
#  WordList(['STRAWBERRY', 'CHARLOTTE', 'BAG']),
#  WordList(['CHARLOTTE', 'BAG', 'RED']),
#  WordList(['BAG', 'RED', '3']),
#  WordList(['RED', '3', 'PIECE']),
#  WordList(['3', 'PIECE', 'RETROSPOT']),
#  WordList(['PIECE', 'RETROSPOT', 'CUTLERY']),
#  WordList(['RETROSPOT', 'CUTLERY', 'SET']),
#  WordList(['CUTLERY', 'SET', 'BLUE']),
#  WordList(['SET', 'BLUE', '3']),
#  WordList(['BLUE', '3', 'PIECE']),
#  WordList(['3', 'PIECE', 'POLKADOT']),
#  WordList(['PIECE', 'POLKADOT', 'CUTLERY']),
#  WordList(['POLKADOT', 'CUTLERY', 'SET']),
#  WordList(['CUTLERY', 'SET', 'SET/6']),
#  WordList(['SET', 'SET/6', 'RED']),
#  WordList(['SET/6', 'RED', 'SPOTTY']),
#  WordList(['RED', 'SPOTTY', 'PAPER']),
#  WordList(['SPOTTY', 'PAPER', 'PLATES']),
#  WordList(['PAPER', 'PLATES', 'LUNCH']),
#  WordList(['PLATES', 'LUNCH', 'BAG']),
#  WordList(['LUNCH', 'BAG', 'RED']),
#  WordList(['BAG', 'RED', 'RETROSPOT']),
#  WordList(['RED', 'RETROSPOT', 'STRAWBERRY']),
#  WordList(['RETROSPOT', 'STRAWBERRY', 'LUNCH']),
#  WordList(['STRAWBERRY', 'LUNCH', 'BOX']),
#  WordList(['LUNCH', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'CUTLERY']),
#  WordList(['WITH', 'CUTLERY', 'LUNCH']),
#  WordList(['CUTLERY', 'LUNCH', 'BOX']),
#  WordList(['LUNCH', 'BOX', 'WITH']),
#  WordList(['BOX', 'WITH', 'CUTLERY']),
#  WordList(['WITH', 'CUTLERY', 'RETROSPOT']),
#  WordList(['CUTLERY', 'RETROSPOT', 'PACK']),
#  WordList(['RETROSPOT', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '72']),
#  WordList(['OF', '72', 'RETROSPOT']),
#  WordList(['72', 'RETROSPOT', 'CAKE']),
#  WordList(['RETROSPOT', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', 'PACK']),
#  WordList(['CASES', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '60']),
#  WordList(['OF', '60', 'DINOSAUR']),
#  WordList(['60', 'DINOSAUR', 'CAKE']),
#  WordList(['DINOSAUR', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', 'PACK']),
#  WordList(['CASES', 'PACK', 'OF']),
#  WordList(['PACK', 'OF', '60']),
#  WordList(['OF', '60', 'PINK']),
#  WordList(['60', 'PINK', 'PAISLEY']),
#  WordList(['PINK', 'PAISLEY', 'CAKE']),
#  WordList(['PAISLEY', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', '60']),
#  WordList(['CASES', '60', 'TEATIME']),
#  WordList(['60', 'TEATIME', 'FAIRY']),
#  WordList(['TEATIME', 'FAIRY', 'CAKE']),
#  WordList(['FAIRY', 'CAKE', 'CASES']),
#  WordList(['CAKE', 'CASES', 'TOMATO']),
#  WordList(['CASES', 'TOMATO', 'CHARLIE+LOLA']),
#  WordList(['TOMATO', 'CHARLIE+LOLA', 'COASTER']),
#  WordList(['CHARLIE+LOLA', 'COASTER', 'SET']),
#  WordList(['COASTER', 'SET', 'CHARLIE']),
#  WordList(['SET', 'CHARLIE', 'LOLA']),
#  WordList(['CHARLIE', 'LOLA', 'WASTEPAPER']),
#  WordList(['LOLA', 'WASTEPAPER', 'BIN']),
#  WordList(['WASTEPAPER', 'BIN', 'FLORA']),
#  WordList(['BIN', 'FLORA', 'RED']),
#  WordList(['FLORA', 'RED', 'CHARLIE+LOLA']),
#  WordList(['RED', 'CHARLIE+LOLA', 'PERSONAL']),
#  WordList(['CHARLIE+LOLA', 'PERSONAL', 'DOORSIGN']),
#  WordList(['PERSONAL', 'DOORSIGN', 'JUMBO']),
#  WordList(['DOORSIGN', 'JUMBO', 'STORAGE']),
#  WordList(['JUMBO', 'STORAGE', 'BAG']),
#  WordList(['STORAGE', 'BAG', 'SUKI']),
#  WordList(['BAG', 'SUKI', 'JUMBO']),
#  WordList(['SUKI', 'JUMBO', 'BAG']),
#  WordList(['JUMBO', 'BAG', 'PINK']),
#  WordList(['BAG', 'PINK', 'VINTAGE']),
#  WordList(['PINK', 'VINTAGE', 'PAISLEY']),
#  WordList(['VINTAGE', 'PAISLEY', 'PARTY']),
#  WordList(['PAISLEY', 'PARTY', 'PIZZA']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'RED']),
#  WordList(['DISH', 'RED', 'RETROSPOT']),
#  WordList(['RED', 'RETROSPOT', 'PARTY']),
#  WordList(['RETROSPOT', 'PARTY', 'PIZZA']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'BLUE']),
#  WordList(['DISH', 'BLUE', 'POLKADOT']),
#  WordList(['BLUE', 'POLKADOT', 'PARTY']),
#  WordList(['POLKADOT', 'PARTY', 'PIZZA']),
#  WordList(['PARTY', 'PIZZA', 'DISH']),
#  WordList(['PIZZA', 'DISH', 'PINK']),
#  WordList(['DISH', 'PINK', 'POLKADOT']),
#  WordList(['PINK', 'POLKADOT', 'RECYCLING']),
#  WordList(['POLKADOT', 'RECYCLING', 'BAG']),
#  WordList(['RECYCLING', 'BAG', 'RETROSPOT']),
#  WordList(['BAG', 'RETROSPOT', 'TOY']),
#  WordList(['RETROSPOT', 'TOY', 'TIDY']),
#  WordList(['TOY', 'TIDY', 'PINK']),
#  ...]

# %%
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER WHITE METAL LANTERN CREAM CUPID HEARTS COAT HANGER KNITTED UNION FLAG HOT WATER BOTTLE RED WOOLLY HOTTIE WHITE HEART SET 7 BABUSHKA NESTING BOXES GLASS STAR FROSTED T-LIGHT HOLDER HAND WARMER UNION JACK HAND WARMER RED POLKA DOT EDWARDIAN PARASOL RED RETRO COFFEE MUGS ASSORTED SAVE THE PLANET MUG VINTAGE BILLBOARD DRINK ME MUG VINTAGE BILLBOARD LOVE/HATE MUG WOOD 2 DRAWER CABINET WHITE FINISH WOOD S/3 CABINET ANT WHITE FINISH WOODEN PICTURE FRAME WHITE FINISH WOODEN FRAME ANTIQUE WHITE  EDWARDIAN PARASOL BLACK IVORY EMBROIDERED QUILT  JUMBO SHOPPER VINTAGE RED PAISLEY HAND WARMER RED RETROSPOT GIN AND TONIC MUG COLOUR GLASS STAR T-LIGHT HOLDER YOU\'RE CONFUSING ME METAL SIGN  ASSORTED COLOUR BIRD ORNAMENT POPPY\'S PLAYHOUSE BEDROOM  POPPY\'S PLAYHOUSE KITCHEN FELTCRAFT PRINCESS CHARLOTTE DOLL IVORY KNITTED MUG COSY  BOX OF 6 ASSORTED COLOUR TEASPOONS BOX OF VINTAGE JIGSAW BLOCKS  BOX OF VINTAGE ALPHABET BLOCKS HOME BUILDING BLOCK WORD LOVE BUILDING BLOCK WORD RECIPE BOX WITH METAL HEART DOORMAT NEW ENGLAND JAM MAKING SET WITH JARS RED COAT RACK PARIS FASHION YELLOW COAT RACK PARIS FASHION BLUE COAT RACK PARIS FASHION BATH BUILDING BLOCK WORD FELTCRAFT DOLL EMILY WRAP ENGLISH ROSE  PHOTO FRAME CORNICE WRAP DOLLY GIRL WRAP DOILEY DESIGN SET OF 12  VINTAGE POSTCARD SET SET OF 6 VINTAGE NOTELETS KIT SWEETHEART WIRE WALL TIDY SET OF 6 SPICE TINS PANTRY DESIGN JAM MAKING SET PRINTED HOMEMADE JAM SCENTED CANDLES SET OF 3 CAKE TINS PANTRY DESIGN  PICTURE DOMINOES PINK CREAM FELT CRAFT TRINKET BOX  MAKE YOUR OWN FLOWERPOWER CARD KIT GLASS  BEURRE DISH DOORMAT ENGLISH ROSE  DOORMAT WELCOME TO OUR HOME WOODEN UNION JACK BUNTING WOODEN ROUNDERS GARDEN SET  PARTY BUNTING KEY FOB  FRONT  DOOR  KEY FOB  BACK DOOR  KEY FOB  GARAGE DESIGN KEY FOB  SHED 6 RIBBONS RUSTIC CHARM IVORY SWEETHEART WIRE LETTER RACK  TOILET SIGN OCCUPIED OR VACANT REGENCY CAKE FORK REGENCY TEA SPOON REGENCY SUGAR TONGS REGENCY TEA STRAINER REGENCY CAKE SLICE TREASURE ISLAND BOOK BOX ABC TREASURE BOOK BOX  TRAVEL CARD WALLET FLOWER MEADOW TRAVEL CARD WALLET VINTAGE TICKET EDWARDIAN HEART PHOTO FRAME FELTCRAFT GIRL AMELIE KIT FOOD COVER WITH BEADS SET 2  REGENCY CAKESTAND 3 TIER VINTAGE UNION JACK BUNTING LARGE ANTIQUE WHITE PHOTO FRAME PARISIENNE CURIO CABINET PARISIENNE KEY CABINET  PARISIENNE SEWING BOX PARISIENNE JEWELLERY DRAWER  SMALL PARISIENNE HEART PHOTO FRAME  GLASS BON BON JAR CLASSIC SUGAR DISPENSER DOILEY STORAGE TIN SET OF 4 KNICK KNACK TINS DOILEY  REGENCY MILK JUG PINK  REGENCY TEAPOT ROSES  SET OF 3 REGENCY CAKE TINS DRAWER KNOB CRACKLE GLAZE IVORY DRAWER KNOB CRACKLE GLAZE PINK DRAWER KNOB CRACKLE GLAZE GREEN DRAWER KNOB CRACKLE GLAZE BLUE FRENCH ENAMEL CANDLEHOLDER PAPER BUNTING RETROSPOT PAPER BUNTING VINTAGE PAISLEY PAPER BUNTING COLOURED LACE WRAP PAISLEY PARK  WRAP RED DOILEY WRAP GINGHAM ROSE  RIBBON REEL CHRISTMAS SOCK BAUBLE 3 RAFFIA RIBBONS VINTAGE CHRISTMAS TRADITIONAL KNITTING NANCY DOORMAT WELCOME PUPPIES CHILDREN\'S APRON DOLLY GIRL  CHILDRENS APRON SPACEBOY DESIGN EMBROIDERED RIBBON REEL SALLY  EMBROIDERED RIBBON REEL SUSIE  EMBROIDERED RIBBON REEL EMILY  PANTRY MAGNETIC  SHOPPING LIST SET OF 6 SNACK LOAF BAKING CASES SET OF 12 MINI LOAF BAKING CASES DRAWER KNOB VINTAGE GLASS BALL CARD HOLDER LOVE BIRD LARGE  FOOT STOOL HOME SWEET HOME  PETIT TRAY CHIC SWEET HEART CAKE CARRIER PACK OF SIX LED TEA LIGHTS 3 RAFFIA RIBBONS 50\'S CHRISTMAS  PAPER CHAIN KIT 50\'S CHRISTMAS  SCANDINAVIAN REDS RIBBONS Manual BISCUIT TIN VINTAGE GREEN ROUND CAKE TIN VINTAGE GREEN 3 TIER CAKE TIN GREEN AND CREAM PACK OF 20 NAPKINS PANTRY DESIGN PACK OF 6 BIRDY GIFT TAGS PAPER CHAIN KIT EMPIRE STRAWBERRY CERAMIC TRINKET BOX NATURAL SLATE HEART CHALKBOARD  PACK OF 12 50\'S CHRISTMAS TISSUES HEART SHAPED HOLLY WREATH 36 DOILIES VINTAGE CHRISTMAS ROLL WRAP 50\'S CHRISTMAS ROLL WRAP VINTAGE SPOT  BOX OF 6 MINI 50\'S CRACKERS 6 GIFT TAGS 50\'S CHRISTMAS  ANTIQUE SILVER T-LIGHT GLASS SET OF 6 RIBBONS VINTAGE CHRISTMAS 60 CAKE CASES VIN ...

# %%
"_".join(w for word in test for w in work_df.Description.unique().split())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 "_".join(w for word in test for w in work_df.Description.unique().split())
#
# NameError: name 'test' is not defined

# %%
work_df.merge(\
work_df[['CustomerID','InvoiceNo','InvoiceDate']]\
.drop_duplicates()\
.sort_values(by=['CustomerID','InvoiceNo','InvoiceDate'], ascending=True)\
.groupby(['CustomerID','InvoiceNo'])['InvoiceDate'].diff().dt.days.fillna(0)\
.to_frame().reset_index().rename(columns={'index':'CustomerID'})\
, on=['CustomerID','InvoiceNo'], how='left')

# %%
train_df = df.loc[df.InvoiceDate < df.InvoiceDate.min() + timedelta(days=30 * 11)]

# %%
test_df = df[~df.index.isin(train_df.index)]

# %%
test_df.InvoiceDate.min(), test_df.InvoiceDate.max()
